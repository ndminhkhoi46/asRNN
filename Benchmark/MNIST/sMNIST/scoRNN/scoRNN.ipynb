# %%
root_path = '/content/drive/My Drive/Colab Notebooks/Paper/EXP/'
expr_path = root_path + 'Benchmark/MNIST/sMNIST/scoRNN'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import_path = [root_path + subpath for subpath in ['sources/', 'sources/expRNN/']]
for path in import_path:
  sys.path.append(path)

# %%
import sys
import argparse
sys.argv = ['']
parser = argparse.ArgumentParser(description='scoRNN MNIST Task')
parser.add_argument('--batch_size', type=int, default=128)
parser.add_argument('--hidden_size', type=int, default=170)
parser.add_argument('--epochs', type=int, default=70)
parser.add_argument('--use_adam', type=bool, default=False)
parser.add_argument('--adam_lr', type=float, default=1e-3)
parser.add_argument('--rmsprop_lr', type=float, default=7e-4)
parser.add_argument('--rmsprop_constr_lr', type=float, default=7e-5)
parser.add_argument('--alpha', type=float, default=0.99)
parser.add_argument('--clip_norm', type=float, default=-1)
parser.add_argument("--permute", action="store_true", default = False)
parser.add_argument("-m", "--mode",
                    choices=["exprnn", "dtriv", "cayley", "lstm", "rnn"],
                    default="exprnn",
                    type=str)
parser.add_argument('--K', type=str, default="100", help='The K parameter in the dtriv algorithm. It should be a positive integer or "infty".')
parser.add_argument("--init",
                    choices=["cayley", "henaff"],
                    default="cayley",
                    type=str)
parser.add_argument('--random-seed', type=int, default=5544,
                    help='random seed')
parser.add_argument('--rho_rat_den', type=int, default=10)
parser.add_argument('--forget_bias', type=int, default=1)
parser.add_argument('--emsize', type=int, default=0,
                    help='size of word embeddings')
#Setting
#https://arxiv.org/pdf/1901.08428.pdf
#https://arxiv.org/abs/1905.12080
args = parser.parse_args(['--hidden_size', '170', '--epochs', '70', '--rmsprop_lr', '1e-3', '--rmsprop_constr_lr', '1e-4', '-mcayley', '--rho_rat_den', '10'])
print(args)
# Out:
# Namespace(K='100', adam_lr=0.001, alpha=0.99, batch_size=128, clip_norm=-1, clip_val=-1, emsize=0, epochs=70, forget_bias=1, hidden_size=170, init='cayley', mode='cayley', permute=False, random_seed=5544, rho_rat_den=10, rmsprop_constr_lr=0.0001, rmsprop_lr=0.001, use_adam=False)

# %%
import torch
import numpy as np
import random
import os
# Fix seed across experiments
# Same seed as that used in "Orthogonal Recurrent Neural Networks with Scaled Cayley Transform"
# https://github.com/SpartinStuff/scoRNN/blob/master/scoRNN_copying.py#L79
torch.use_deterministic_algorithms(True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(args.random_seed)
np.random.seed(args.random_seed)
random.seed(args.random_seed)

#Deterministic training
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ":4096:8" #increase library footprint in GPU memory by approximately 24MiB
#os.environ['CUBLAS_WORKSPACE_CONFIG'] = ":16:8" #(may limit overall performance)"

# %%
from trivializations import cayley_map, expm
from initialization import henaff_init_, cayley_init_
from data_module import MNISTDataModule
from torch.nn import Embedding

sequence_length = 784
hidden_size = args.hidden_size
batch_size  = args.batch_size
epochs      = args.epochs
device      = device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_first = True
many_to_many = False
epochs_to_save = 1

if args.init == "cayley":
    init =  cayley_init_
elif args.init == "henaff":
    init = henaff_init_

if args.K != "infty":
    args.K = int(args.K)
if args.mode == "exprnn":
    mode = "static"
    param = expm
elif args.mode == "dtriv":
    # We use 100 as the default to project back to the manifold.
    # This parameter does not really affect the convergence of the algorithms, even for K=1
    mode = ("dynamic", args.K, 100)
    param = expm
elif args.mode == "cayley":
    mode = "static"
    param = cayley_map

#Setting up data module
# Load data   
dataset_path = root_path + 'Dataset/MNIST/'
if args.permute:
  datamodule = MNISTDataModule(sequence_length, 784 // sequence_length, batch_size, dataset_path, permute_seed = 92916)
else:
  datamodule = MNISTDataModule(sequence_length, 784 // sequence_length, batch_size, dataset_path, permute_seed = None)

if args.emsize > 0:
  embed_layer = Embedding(datamodule.input_size, args.emsize) # Token2Embeddings
  input_size = args.emsize
else:
  embed_layer = None
  input_size = datamodule.input_size

# %%
from model_loader import Model
from custom_modules import AMSAF_SVD
from orthogonal import modrelu

#Initialize Model
nonlinearity = modrelu(hidden_size)
model = Model(input_size, hidden_size, datamodule.output_size, nonlinearity, initializer_skew = init,
              mode = mode, param = param, args=args, embed_layer=embed_layer, batch_first=batch_first, many_to_many = many_to_many).to(device)
#Initialize Optimizers
unconstrained_parameters = []
constrained_parameters = []

for name, p in model.named_parameters():
    if any(map(name.__contains__, ['recurrent_kernel'])):
        constrained_parameters.append(p)
    else:
        unconstrained_parameters.append(p)
if args.use_adam:
  adam_optim = torch.optim.Adam(unconstrained_parameters, lr=args.adam_lr)
  rmsprop_optim = torch.optim.RMSprop(constrained_parameters, lr=args.rmsprop_constr_lr)
else:
  rmsprop_optim = torch.optim.RMSprop([
                  {'params': unconstrained_parameters},
                  {'params': constrained_parameters, 'lr': args.rmsprop_constr_lr}
              ], lr=args.rmsprop_lr, alpha = args.alpha)
  adam_optim = None

optim_list = [optim for optim in [rmsprop_optim, adam_optim] if optim]
model.setup_optimizer_list(optim_list)

column_names = ['Epoch', 'Training Loss', 'Training Accuracy', 'Test Loss', 'Test Accuracy']
train_log = model.load_log_df(epochs_to_save, expr_path, column_names)

# %%
def pred(model, datamodule, training = True):
  global device
  total_loss = 0.0
  total_acc = 0.0
  sample_num = 0

  if training:
    data_enum = datamodule.train_enum()
    data_len = datamodule.train_len
  else:
    data_enum = datamodule.test_enum()
    data_len = datamodule.test_len

  for batch_x, batch_y in data_enum:
      batch_x, batch_y = batch_x.to(device).view(-1, datamodule.sequence_length, datamodule.input_size), batch_y.to(device)
      state = None
      state = model.state_reprocess(batch_x, state)

      logits = model.compute_logits(batch_x, state)
      loss = model.loss(logits, batch_y)
      if training:
        model.gradient_descent(loss)
      total_loss += loss.item() * batch_x.size(0)
      batch_correct = model.correct(logits, batch_y).item()
      total_acc += batch_correct
      sample_num += batch_x.size(0)
      
      if training: #For tracking training progress
        print('Train Epoch: {} [{}/{} ({:.2f}%)]\tBatch Loss: {:.3f}\t\tBatch Accuracy: {:.2f}%'.format(model.step+1, sample_num, datamodule.train_len,
                    model.average_value(100. * sample_num, datamodule.train_len, 2), loss.item(), model.average_value(100 * batch_correct, len(batch_x), 2)))
        
  total_loss = model.average_value(total_loss, data_len, 3)
  total_acc = model.average_value(100 * total_acc, data_len, 2)
  return total_loss, total_acc

# %%
def save_model(epochs_to_save, experiment_path):
  if (model.step % epochs_to_save == 0):
    if ((model.step // epochs_to_save) % 2) == 1:
      model.save_state(experiment_path+'/last_odd.ckpt')
    else:
      model.save_state(experiment_path+'/last_even.ckpt')

# %%
import pandas as pd
#Training
model.train()
for epoch in range(model.step+1, epochs):
  train_loss, train_acc = pred(model, datamodule, training = True)
  print('Train Epoch {}| Loss: {:.3f}\tAccuracy: {:.2f}%'.format(epoch, train_loss, train_acc))

  model.eval()
  with torch.no_grad():
      test_loss, test_acc = pred(model, datamodule, training = False)
  if len(train_log) == 0:
    best_test_acc = test_acc
  else:
    best_test_acc = max(train_log["Test Accuracy"].max(), test_acc)
  print('Test Epoch {}| Loss: {:.3f}\tAccuracy: {:.2f}%\tBest Accuracy: {:.2f}'.format(epoch, test_loss, test_acc, best_test_acc))       

  model.step = epoch #update_log_df and save_model requires this command
  new_row = pd.Series({"Epoch": epoch, "Training Loss": train_loss, "Training Accuracy": train_acc,
                        "Test Loss": test_loss, 'Test Accuracy': test_acc})
  train_log = model.update_log_df(new_row, train_log, expr_path+'/train_log.pkl')
  save_model(epochs_to_save, expr_path)
  model.train()
# Out:
# Train Epoch: 0 [128/60000 (0.21%)]	Batch Loss: 7.607		Batch Accuracy: 10.94%
# Train Epoch: 0 [256/60000 (0.43%)]	Batch Loss: 8.741		Batch Accuracy: 10.94%
# Train Epoch: 0 [384/60000 (0.64%)]	Batch Loss: 4.161		Batch Accuracy: 12.50%
# Train Epoch: 0 [512/60000 (0.85%)]	Batch Loss: 4.298		Batch Accuracy: 21.88%
# Train Epoch: 0 [640/60000 (1.07%)]	Batch Loss: 2.210		Batch Accuracy: 41.41%
# Train Epoch: 0 [768/60000 (1.28%)]	Batch Loss: 2.048		Batch Accuracy: 35.16%
# Train Epoch: 0 [896/60000 (1.49%)]	Batch Loss: 2.018		Batch Accuracy: 38.28%
# Train Epoch: 0 [1024/60000 (1.71%)]	Batch Loss: 1.494		Batch Accuracy: 51.56%
# Train Epoch: 0 [1152/60000 (1.92%)]	Batch Loss: 1.702		Batch Accuracy: 49.22%
# Train Epoch: 0 [1280/60000 (2.13%)]	Batch Loss: 1.721		Batch Accuracy: 53.12%
# Train Epoch: 0 [1408/60000 (2.35%)]	Batch Loss: 1.438		Batch Accuracy: 53.91%
# Train Epoch: 0 [1536/60000 (2.56%)]	Batch Loss: 1.340		Batch Accuracy: 56.25%
# Train Epoch: 0 [1664/60000 (2.77%)]	Batch Loss: 1.319		Batch Accuracy: 61.72%
# Train Epoch: 0 [1792/60000 (2.99%)]	Batch Loss: 1.117		Batch Accuracy: 61.72%
# Train Epoch: 0 [1920/60000 (3.20%)]	Batch Loss: 1.309		Batch Accuracy: 61.72%
# Train Epoch: 0 [2048/60000 (3.41%)]	Batch Loss: 1.244		Batch Accuracy: 59.38%
# Train Epoch: 0 [2176/60000 (3.63%)]	Batch Loss: 1.071		Batch Accuracy: 65.62%
# Train Epoch: 0 [2304/60000 (3.84%)]	Batch Loss: 1.045		Batch Accuracy: 65.62%
# Train Epoch: 0 [2432/60000 (4.05%)]	Batch Loss: 1.144		Batch Accuracy: 59.38%
# Train Epoch: 0 [2560/60000 (4.27%)]	Batch Loss: 1.105		Batch Accuracy: 62.50%
# Train Epoch: 0 [2688/60000 (4.48%)]	Batch Loss: 1.203		Batch Accuracy: 64.06%
# Train Epoch: 0 [2816/60000 (4.69%)]	Batch Loss: 1.112		Batch Accuracy: 64.84%
# Train Epoch: 0 [2944/60000 (4.91%)]	Batch Loss: 0.961		Batch Accuracy: 66.41%
# Train Epoch: 0 [3072/60000 (5.12%)]	Batch Loss: 1.084		Batch Accuracy: 66.41%
# Train Epoch: 0 [3200/60000 (5.33%)]	Batch Loss: 1.044		Batch Accuracy: 73.44%
# Train Epoch: 0 [3328/60000 (5.55%)]	Batch Loss: 1.053		Batch Accuracy: 65.62%
# Train Epoch: 0 [3456/60000 (5.76%)]	Batch Loss: 1.188		Batch Accuracy: 67.97%
# Train Epoch: 0 [3584/60000 (5.97%)]	Batch Loss: 1.190		Batch Accuracy: 60.16%
# Train Epoch: 0 [3712/60000 (6.19%)]	Batch Loss: 1.136		Batch Accuracy: 60.16%
# Train Epoch: 0 [3840/60000 (6.40%)]	Batch Loss: 0.893		Batch Accuracy: 75.00%
# Train Epoch: 0 [3968/60000 (6.61%)]	Batch Loss: 0.677		Batch Accuracy: 79.69%
# Train Epoch: 0 [4096/60000 (6.83%)]	Batch Loss: 0.901		Batch Accuracy: 72.66%
# Train Epoch: 0 [4224/60000 (7.04%)]	Batch Loss: 0.902		Batch Accuracy: 71.09%
# Train Epoch: 0 [4352/60000 (7.25%)]	Batch Loss: 0.949		Batch Accuracy: 69.53%
# Train Epoch: 0 [4480/60000 (7.47%)]	Batch Loss: 1.061		Batch Accuracy: 67.97%
# Train Epoch: 0 [4608/60000 (7.68%)]	Batch Loss: 1.380		Batch Accuracy: 62.50%
# Train Epoch: 0 [4736/60000 (7.89%)]	Batch Loss: 1.133		Batch Accuracy: 63.28%
# Train Epoch: 0 [4864/60000 (8.11%)]	Batch Loss: 1.396		Batch Accuracy: 60.16%
# Train Epoch: 0 [4992/60000 (8.32%)]	Batch Loss: 0.850		Batch Accuracy: 76.56%
# Train Epoch: 0 [5120/60000 (8.53%)]	Batch Loss: 0.770		Batch Accuracy: 76.56%
# Train Epoch: 0 [5248/60000 (8.75%)]	Batch Loss: 0.643		Batch Accuracy: 75.00%
# Train Epoch: 0 [5376/60000 (8.96%)]	Batch Loss: 0.760		Batch Accuracy: 76.56%
# Train Epoch: 0 [5504/60000 (9.17%)]	Batch Loss: 0.882		Batch Accuracy: 74.22%
# Train Epoch: 0 [5632/60000 (9.39%)]	Batch Loss: 0.907		Batch Accuracy: 71.09%
# Train Epoch: 0 [5760/60000 (9.60%)]	Batch Loss: 0.718		Batch Accuracy: 80.47%
# Train Epoch: 0 [5888/60000 (9.81%)]	Batch Loss: 0.926		Batch Accuracy: 75.78%
# Train Epoch: 0 [6016/60000 (10.03%)]	Batch Loss: 0.849		Batch Accuracy: 74.22%
# Train Epoch: 0 [6144/60000 (10.24%)]	Batch Loss: 0.862		Batch Accuracy: 75.78%
# Train Epoch: 0 [6272/60000 (10.45%)]	Batch Loss: 0.820		Batch Accuracy: 76.56%
# Train Epoch: 0 [6400/60000 (10.67%)]	Batch Loss: 0.753		Batch Accuracy: 78.12%
# Train Epoch: 0 [6528/60000 (10.88%)]	Batch Loss: 0.709		Batch Accuracy: 71.88%
# Train Epoch: 0 [6656/60000 (11.09%)]	Batch Loss: 0.785		Batch Accuracy: 79.69%
# Train Epoch: 0 [6784/60000 (11.31%)]	Batch Loss: 0.759		Batch Accuracy: 77.34%
# Train Epoch: 0 [6912/60000 (11.52%)]	Batch Loss: 0.654		Batch Accuracy: 78.91%
# Train Epoch: 0 [7040/60000 (11.73%)]	Batch Loss: 0.765		Batch Accuracy: 78.12%
# Train Epoch: 0 [7168/60000 (11.95%)]	Batch Loss: 0.963		Batch Accuracy: 74.22%
# Train Epoch: 0 [7296/60000 (12.16%)]	Batch Loss: 0.899		Batch Accuracy: 76.56%
# Train Epoch: 0 [7424/60000 (12.37%)]	Batch Loss: 0.800		Batch Accuracy: 77.34%
# Train Epoch: 0 [7552/60000 (12.59%)]	Batch Loss: 0.700		Batch Accuracy: 78.12%
# Train Epoch: 0 [7680/60000 (12.80%)]	Batch Loss: 0.712		Batch Accuracy: 77.34%
# Train Epoch: 0 [7808/60000 (13.01%)]	Batch Loss: 0.679		Batch Accuracy: 81.25%
# Train Epoch: 0 [7936/60000 (13.23%)]	Batch Loss: 0.660		Batch Accuracy: 79.69%
# Train Epoch: 0 [8064/60000 (13.44%)]	Batch Loss: 0.683		Batch Accuracy: 78.12%
# Train Epoch: 0 [8192/60000 (13.65%)]	Batch Loss: 0.736		Batch Accuracy: 78.12%
# Train Epoch: 0 [8320/60000 (13.87%)]	Batch Loss: 0.889		Batch Accuracy: 71.88%
# Train Epoch: 0 [8448/60000 (14.08%)]	Batch Loss: 0.568		Batch Accuracy: 79.69%
# Train Epoch: 0 [8576/60000 (14.29%)]	Batch Loss: 0.821		Batch Accuracy: 75.00%
# Train Epoch: 0 [8704/60000 (14.51%)]	Batch Loss: 0.739		Batch Accuracy: 77.34%
# Train Epoch: 0 [8832/60000 (14.72%)]	Batch Loss: 0.949		Batch Accuracy: 76.56%
# Train Epoch: 0 [8960/60000 (14.93%)]	Batch Loss: 0.721		Batch Accuracy: 78.91%
# Train Epoch: 0 [9088/60000 (15.15%)]	Batch Loss: 0.642		Batch Accuracy: 78.12%
# Train Epoch: 0 [9216/60000 (15.36%)]	Batch Loss: 0.910		Batch Accuracy: 76.56%
# Train Epoch: 0 [9344/60000 (15.57%)]	Batch Loss: 0.731		Batch Accuracy: 80.47%
# Train Epoch: 0 [9472/60000 (15.79%)]	Batch Loss: 0.578		Batch Accuracy: 83.59%
# Train Epoch: 0 [9600/60000 (16.00%)]	Batch Loss: 0.735		Batch Accuracy: 74.22%
# Train Epoch: 0 [9728/60000 (16.21%)]	Batch Loss: 0.753		Batch Accuracy: 79.69%
# Train Epoch: 0 [9856/60000 (16.43%)]	Batch Loss: 0.749		Batch Accuracy: 82.03%
# Train Epoch: 0 [9984/60000 (16.64%)]	Batch Loss: 0.718		Batch Accuracy: 78.91%
# Train Epoch: 0 [10112/60000 (16.85%)]	Batch Loss: 0.888		Batch Accuracy: 75.78%
# Train Epoch: 0 [10240/60000 (17.07%)]	Batch Loss: 0.780		Batch Accuracy: 72.66%
# Train Epoch: 0 [10368/60000 (17.28%)]	Batch Loss: 0.750		Batch Accuracy: 77.34%
# Train Epoch: 0 [10496/60000 (17.49%)]	Batch Loss: 0.593		Batch Accuracy: 81.25%
# Train Epoch: 0 [10624/60000 (17.71%)]	Batch Loss: 0.649		Batch Accuracy: 81.25%
# Train Epoch: 0 [10752/60000 (17.92%)]	Batch Loss: 0.743		Batch Accuracy: 78.91%
# Train Epoch: 0 [10880/60000 (18.13%)]	Batch Loss: 0.721		Batch Accuracy: 77.34%
# Train Epoch: 0 [11008/60000 (18.35%)]	Batch Loss: 0.872		Batch Accuracy: 71.88%
# Train Epoch: 0 [11136/60000 (18.56%)]	Batch Loss: 1.018		Batch Accuracy: 67.97%
# Train Epoch: 0 [11264/60000 (18.77%)]	Batch Loss: 0.882		Batch Accuracy: 71.09%
# Train Epoch: 0 [11392/60000 (18.99%)]	Batch Loss: 0.854		Batch Accuracy: 73.44%
# Train Epoch: 0 [11520/60000 (19.20%)]	Batch Loss: 0.500		Batch Accuracy: 85.16%
# Train Epoch: 0 [11648/60000 (19.41%)]	Batch Loss: 0.843		Batch Accuracy: 75.78%
# Train Epoch: 0 [11776/60000 (19.63%)]	Batch Loss: 0.777		Batch Accuracy: 75.00%
# Train Epoch: 0 [11904/60000 (19.84%)]	Batch Loss: 0.994		Batch Accuracy: 77.34%
# Train Epoch: 0 [12032/60000 (20.05%)]	Batch Loss: 0.848		Batch Accuracy: 77.34%
# Train Epoch: 0 [12160/60000 (20.27%)]	Batch Loss: 0.847		Batch Accuracy: 75.00%
# Train Epoch: 0 [12288/60000 (20.48%)]	Batch Loss: 0.717		Batch Accuracy: 83.59%
# Train Epoch: 0 [12416/60000 (20.69%)]	Batch Loss: 0.776		Batch Accuracy: 77.34%
# Train Epoch: 0 [12544/60000 (20.91%)]	Batch Loss: 0.487		Batch Accuracy: 86.72%
# Train Epoch: 0 [12672/60000 (21.12%)]	Batch Loss: 0.888		Batch Accuracy: 71.09%
# Train Epoch: 0 [12800/60000 (21.33%)]	Batch Loss: 0.735		Batch Accuracy: 80.47%
# Train Epoch: 0 [12928/60000 (21.55%)]	Batch Loss: 0.794		Batch Accuracy: 78.91%
# Train Epoch: 0 [13056/60000 (21.76%)]	Batch Loss: 0.610		Batch Accuracy: 79.69%
# Train Epoch: 0 [13184/60000 (21.97%)]	Batch Loss: 0.562		Batch Accuracy: 79.69%
# Train Epoch: 0 [13312/60000 (22.19%)]	Batch Loss: 0.762		Batch Accuracy: 82.03%
# Train Epoch: 0 [13440/60000 (22.40%)]	Batch Loss: 0.520		Batch Accuracy: 80.47%
# Train Epoch: 0 [13568/60000 (22.61%)]	Batch Loss: 0.591		Batch Accuracy: 82.03%
# Train Epoch: 0 [13696/60000 (22.83%)]	Batch Loss: 0.805		Batch Accuracy: 77.34%
# Train Epoch: 0 [13824/60000 (23.04%)]	Batch Loss: 0.802		Batch Accuracy: 75.78%
# Train Epoch: 0 [13952/60000 (23.25%)]	Batch Loss: 0.740		Batch Accuracy: 78.12%
# Train Epoch: 0 [14080/60000 (23.47%)]	Batch Loss: 0.510		Batch Accuracy: 83.59%
# Train Epoch: 0 [14208/60000 (23.68%)]	Batch Loss: 0.635		Batch Accuracy: 82.81%
# Train Epoch: 0 [14336/60000 (23.89%)]	Batch Loss: 0.712		Batch Accuracy: 73.44%
# Train Epoch: 0 [14464/60000 (24.11%)]	Batch Loss: 0.586		Batch Accuracy: 79.69%
# Train Epoch: 0 [14592/60000 (24.32%)]	Batch Loss: 0.639		Batch Accuracy: 85.94%
# Train Epoch: 0 [14720/60000 (24.53%)]	Batch Loss: 0.527		Batch Accuracy: 82.03%
# Train Epoch: 0 [14848/60000 (24.75%)]	Batch Loss: 0.632		Batch Accuracy: 80.47%
# Train Epoch: 0 [14976/60000 (24.96%)]	Batch Loss: 0.656		Batch Accuracy: 78.91%
# Train Epoch: 0 [15104/60000 (25.17%)]	Batch Loss: 0.745		Batch Accuracy: 77.34%
# Train Epoch: 0 [15232/60000 (25.39%)]	Batch Loss: 0.898		Batch Accuracy: 82.03%
# Train Epoch: 0 [15360/60000 (25.60%)]	Batch Loss: 0.519		Batch Accuracy: 84.38%
# Train Epoch: 0 [15488/60000 (25.81%)]	Batch Loss: 0.484		Batch Accuracy: 84.38%
# Train Epoch: 0 [15616/60000 (26.03%)]	Batch Loss: 0.758		Batch Accuracy: 76.56%
# Train Epoch: 0 [15744/60000 (26.24%)]	Batch Loss: 0.688		Batch Accuracy: 78.91%
# Train Epoch: 0 [15872/60000 (26.45%)]	Batch Loss: 0.664		Batch Accuracy: 80.47%
# Train Epoch: 0 [16000/60000 (26.67%)]	Batch Loss: 0.706		Batch Accuracy: 84.38%
# Train Epoch: 0 [16128/60000 (26.88%)]	Batch Loss: 0.684		Batch Accuracy: 82.03%
# Train Epoch: 0 [16256/60000 (27.09%)]	Batch Loss: 0.757		Batch Accuracy: 72.66%
# Train Epoch: 0 [16384/60000 (27.31%)]	Batch Loss: 0.739		Batch Accuracy: 75.78%
# Train Epoch: 0 [16512/60000 (27.52%)]	Batch Loss: 0.643		Batch Accuracy: 81.25%
# Train Epoch: 0 [16640/60000 (27.73%)]	Batch Loss: 0.573		Batch Accuracy: 82.81%
# Train Epoch: 0 [16768/60000 (27.95%)]	Batch Loss: 0.784		Batch Accuracy: 79.69%
# Train Epoch: 0 [16896/60000 (28.16%)]	Batch Loss: 0.590		Batch Accuracy: 83.59%
# Train Epoch: 0 [17024/60000 (28.37%)]	Batch Loss: 0.626		Batch Accuracy: 77.34%
# Train Epoch: 0 [17152/60000 (28.59%)]	Batch Loss: 0.566		Batch Accuracy: 83.59%
# Train Epoch: 0 [17280/60000 (28.80%)]	Batch Loss: 0.504		Batch Accuracy: 84.38%
# Train Epoch: 0 [17408/60000 (29.01%)]	Batch Loss: 0.565		Batch Accuracy: 81.25%
# Train Epoch: 0 [17536/60000 (29.23%)]	Batch Loss: 0.620		Batch Accuracy: 84.38%
# Train Epoch: 0 [17664/60000 (29.44%)]	Batch Loss: 0.610		Batch Accuracy: 80.47%
# Train Epoch: 0 [17792/60000 (29.65%)]	Batch Loss: 0.589		Batch Accuracy: 84.38%
# Train Epoch: 0 [17920/60000 (29.87%)]	Batch Loss: 0.616		Batch Accuracy: 78.12%
# Train Epoch: 0 [18048/60000 (30.08%)]	Batch Loss: 0.472		Batch Accuracy: 84.38%
# Train Epoch: 0 [18176/60000 (30.29%)]	Batch Loss: 0.668		Batch Accuracy: 79.69%
# Train Epoch: 0 [18304/60000 (30.51%)]	Batch Loss: 0.768		Batch Accuracy: 78.91%
# Train Epoch: 0 [18432/60000 (30.72%)]	Batch Loss: 0.524		Batch Accuracy: 83.59%
# Train Epoch: 0 [18560/60000 (30.93%)]	Batch Loss: 0.849		Batch Accuracy: 79.69%
# Train Epoch: 0 [18688/60000 (31.15%)]	Batch Loss: 1.073		Batch Accuracy: 64.06%
# Train Epoch: 0 [18816/60000 (31.36%)]	Batch Loss: 0.860		Batch Accuracy: 75.78%
# Train Epoch: 0 [18944/60000 (31.57%)]	Batch Loss: 0.510		Batch Accuracy: 85.16%
# Train Epoch: 0 [19072/60000 (31.79%)]	Batch Loss: 0.610		Batch Accuracy: 81.25%
# Train Epoch: 0 [19200/60000 (32.00%)]	Batch Loss: 0.513		Batch Accuracy: 82.03%
# Train Epoch: 0 [19328/60000 (32.21%)]	Batch Loss: 0.590		Batch Accuracy: 84.38%
# Train Epoch: 0 [19456/60000 (32.43%)]	Batch Loss: 0.509		Batch Accuracy: 84.38%
# Train Epoch: 0 [19584/60000 (32.64%)]	Batch Loss: 0.605		Batch Accuracy: 81.25%
# Train Epoch: 0 [19712/60000 (32.85%)]	Batch Loss: 0.662		Batch Accuracy: 81.25%
# Train Epoch: 0 [19840/60000 (33.07%)]	Batch Loss: 0.723		Batch Accuracy: 80.47%
# Train Epoch: 0 [19968/60000 (33.28%)]	Batch Loss: 0.556		Batch Accuracy: 85.16%
# Train Epoch: 0 [20096/60000 (33.49%)]	Batch Loss: 0.619		Batch Accuracy: 82.81%
# Train Epoch: 0 [20224/60000 (33.71%)]	Batch Loss: 0.575		Batch Accuracy: 82.03%
# Train Epoch: 0 [20352/60000 (33.92%)]	Batch Loss: 0.584		Batch Accuracy: 85.16%
# Train Epoch: 0 [20480/60000 (34.13%)]	Batch Loss: 0.618		Batch Accuracy: 83.59%
# Train Epoch: 0 [20608/60000 (34.35%)]	Batch Loss: 0.610		Batch Accuracy: 78.12%
# Train Epoch: 0 [20736/60000 (34.56%)]	Batch Loss: 0.555		Batch Accuracy: 77.34%
# Train Epoch: 0 [20864/60000 (34.77%)]	Batch Loss: 0.596		Batch Accuracy: 77.34%
# Train Epoch: 0 [20992/60000 (34.99%)]	Batch Loss: 0.728		Batch Accuracy: 78.91%
# Train Epoch: 0 [21120/60000 (35.20%)]	Batch Loss: 0.599		Batch Accuracy: 78.91%
# Train Epoch: 0 [21248/60000 (35.41%)]	Batch Loss: 0.643		Batch Accuracy: 79.69%
# Train Epoch: 0 [21376/60000 (35.63%)]	Batch Loss: 0.607		Batch Accuracy: 85.16%
# Train Epoch: 0 [21504/60000 (35.84%)]	Batch Loss: 0.520		Batch Accuracy: 81.25%
# Train Epoch: 0 [21632/60000 (36.05%)]	Batch Loss: 0.534		Batch Accuracy: 80.47%
# Train Epoch: 0 [21760/60000 (36.27%)]	Batch Loss: 0.582		Batch Accuracy: 79.69%
# Train Epoch: 0 [21888/60000 (36.48%)]	Batch Loss: 0.535		Batch Accuracy: 82.81%
# Train Epoch: 0 [22016/60000 (36.69%)]	Batch Loss: 0.503		Batch Accuracy: 87.50%
# Train Epoch: 0 [22144/60000 (36.91%)]	Batch Loss: 0.574		Batch Accuracy: 82.81%
# Train Epoch: 0 [22272/60000 (37.12%)]	Batch Loss: 0.547		Batch Accuracy: 85.16%
# Train Epoch: 0 [22400/60000 (37.33%)]	Batch Loss: 0.815		Batch Accuracy: 76.56%
# Train Epoch: 0 [22528/60000 (37.55%)]	Batch Loss: 0.595		Batch Accuracy: 80.47%
# Train Epoch: 0 [22656/60000 (37.76%)]	Batch Loss: 0.501		Batch Accuracy: 84.38%
# Train Epoch: 0 [22784/60000 (37.97%)]	Batch Loss: 0.558		Batch Accuracy: 82.81%
# Train Epoch: 0 [22912/60000 (38.19%)]	Batch Loss: 0.401		Batch Accuracy: 89.84%
# Train Epoch: 0 [23040/60000 (38.40%)]	Batch Loss: 0.456		Batch Accuracy: 84.38%
# Train Epoch: 0 [23168/60000 (38.61%)]	Batch Loss: 0.708		Batch Accuracy: 80.47%
# Train Epoch: 0 [23296/60000 (38.83%)]	Batch Loss: 0.639		Batch Accuracy: 82.03%
# Train Epoch: 0 [23424/60000 (39.04%)]	Batch Loss: 0.686		Batch Accuracy: 77.34%
# Train Epoch: 0 [23552/60000 (39.25%)]	Batch Loss: 0.442		Batch Accuracy: 83.59%
# Train Epoch: 0 [23680/60000 (39.47%)]	Batch Loss: 0.367		Batch Accuracy: 89.84%
# Train Epoch: 0 [23808/60000 (39.68%)]	Batch Loss: 0.739		Batch Accuracy: 75.00%
# Train Epoch: 0 [23936/60000 (39.89%)]	Batch Loss: 0.712		Batch Accuracy: 82.03%
# Train Epoch: 0 [24064/60000 (40.11%)]	Batch Loss: 0.531		Batch Accuracy: 85.94%
# Train Epoch: 0 [24192/60000 (40.32%)]	Batch Loss: 0.480		Batch Accuracy: 86.72%
# Train Epoch: 0 [24320/60000 (40.53%)]	Batch Loss: 0.434		Batch Accuracy: 86.72%
# Train Epoch: 0 [24448/60000 (40.75%)]	Batch Loss: 0.591		Batch Accuracy: 84.38%
# Train Epoch: 0 [24576/60000 (40.96%)]	Batch Loss: 0.666		Batch Accuracy: 80.47%
# Train Epoch: 0 [24704/60000 (41.17%)]	Batch Loss: 0.559		Batch Accuracy: 82.03%
# Train Epoch: 0 [24832/60000 (41.39%)]	Batch Loss: 0.606		Batch Accuracy: 80.47%
# Train Epoch: 0 [24960/60000 (41.60%)]	Batch Loss: 0.709		Batch Accuracy: 81.25%
# Train Epoch: 0 [25088/60000 (41.81%)]	Batch Loss: 0.513		Batch Accuracy: 84.38%
# Train Epoch: 0 [25216/60000 (42.03%)]	Batch Loss: 0.548		Batch Accuracy: 80.47%
# Train Epoch: 0 [25344/60000 (42.24%)]	Batch Loss: 0.500		Batch Accuracy: 84.38%
# Train Epoch: 0 [25472/60000 (42.45%)]	Batch Loss: 0.455		Batch Accuracy: 88.28%
# Train Epoch: 0 [25600/60000 (42.67%)]	Batch Loss: 0.664		Batch Accuracy: 80.47%
# Train Epoch: 0 [25728/60000 (42.88%)]	Batch Loss: 0.440		Batch Accuracy: 89.06%
# Train Epoch: 0 [25856/60000 (43.09%)]	Batch Loss: 0.575		Batch Accuracy: 81.25%
# Train Epoch: 0 [25984/60000 (43.31%)]	Batch Loss: 0.624		Batch Accuracy: 82.03%
# Train Epoch: 0 [26112/60000 (43.52%)]	Batch Loss: 0.399		Batch Accuracy: 85.94%
# Train Epoch: 0 [26240/60000 (43.73%)]	Batch Loss: 0.623		Batch Accuracy: 80.47%
# Train Epoch: 0 [26368/60000 (43.95%)]	Batch Loss: 0.618		Batch Accuracy: 76.56%
# Train Epoch: 0 [26496/60000 (44.16%)]	Batch Loss: 0.663		Batch Accuracy: 80.47%
# Train Epoch: 0 [26624/60000 (44.37%)]	Batch Loss: 0.590		Batch Accuracy: 87.50%
# Train Epoch: 0 [26752/60000 (44.59%)]	Batch Loss: 0.588		Batch Accuracy: 80.47%
# Train Epoch: 0 [26880/60000 (44.80%)]	Batch Loss: 0.476		Batch Accuracy: 83.59%
# Train Epoch: 0 [27008/60000 (45.01%)]	Batch Loss: 0.383		Batch Accuracy: 84.38%
# Train Epoch: 0 [27136/60000 (45.23%)]	Batch Loss: 0.558		Batch Accuracy: 85.16%
# Train Epoch: 0 [27264/60000 (45.44%)]	Batch Loss: 0.653		Batch Accuracy: 78.91%
# Train Epoch: 0 [27392/60000 (45.65%)]	Batch Loss: 0.545		Batch Accuracy: 85.94%
# Train Epoch: 0 [27520/60000 (45.87%)]	Batch Loss: 0.454		Batch Accuracy: 85.94%
# Train Epoch: 0 [27648/60000 (46.08%)]	Batch Loss: 0.334		Batch Accuracy: 89.84%
# Train Epoch: 0 [27776/60000 (46.29%)]	Batch Loss: 0.609		Batch Accuracy: 79.69%
# Train Epoch: 0 [27904/60000 (46.51%)]	Batch Loss: 0.523		Batch Accuracy: 84.38%
# Train Epoch: 0 [28032/60000 (46.72%)]	Batch Loss: 0.599		Batch Accuracy: 81.25%
# Train Epoch: 0 [28160/60000 (46.93%)]	Batch Loss: 0.646		Batch Accuracy: 83.59%
# Train Epoch: 0 [28288/60000 (47.15%)]	Batch Loss: 0.658		Batch Accuracy: 79.69%
# Train Epoch: 0 [28416/60000 (47.36%)]	Batch Loss: 0.776		Batch Accuracy: 76.56%
# Train Epoch: 0 [28544/60000 (47.57%)]	Batch Loss: 0.659		Batch Accuracy: 78.91%
# Train Epoch: 0 [28672/60000 (47.79%)]	Batch Loss: 0.668		Batch Accuracy: 75.00%
# Train Epoch: 0 [28800/60000 (48.00%)]	Batch Loss: 0.603		Batch Accuracy: 78.12%
# Train Epoch: 0 [28928/60000 (48.21%)]	Batch Loss: 0.610		Batch Accuracy: 82.81%
# Train Epoch: 0 [29056/60000 (48.43%)]	Batch Loss: 0.684		Batch Accuracy: 85.16%
# Train Epoch: 0 [29184/60000 (48.64%)]	Batch Loss: 0.623		Batch Accuracy: 82.81%
# Train Epoch: 0 [29312/60000 (48.85%)]	Batch Loss: 0.744		Batch Accuracy: 76.56%
# Train Epoch: 0 [29440/60000 (49.07%)]	Batch Loss: 0.506		Batch Accuracy: 85.16%
# Train Epoch: 0 [29568/60000 (49.28%)]	Batch Loss: 0.608		Batch Accuracy: 75.78%
# Train Epoch: 0 [29696/60000 (49.49%)]	Batch Loss: 0.525		Batch Accuracy: 83.59%
# Train Epoch: 0 [29824/60000 (49.71%)]	Batch Loss: 0.700		Batch Accuracy: 77.34%
# Train Epoch: 0 [29952/60000 (49.92%)]	Batch Loss: 0.439		Batch Accuracy: 89.06%
# Train Epoch: 0 [30080/60000 (50.13%)]	Batch Loss: 0.448		Batch Accuracy: 87.50%
# Train Epoch: 0 [30208/60000 (50.35%)]	Batch Loss: 0.447		Batch Accuracy: 82.81%
# Train Epoch: 0 [30336/60000 (50.56%)]	Batch Loss: 0.550		Batch Accuracy: 85.16%
# Train Epoch: 0 [30464/60000 (50.77%)]	Batch Loss: 0.286		Batch Accuracy: 91.41%
# Train Epoch: 0 [30592/60000 (50.99%)]	Batch Loss: 0.504		Batch Accuracy: 87.50%
# Train Epoch: 0 [30720/60000 (51.20%)]	Batch Loss: 0.471		Batch Accuracy: 85.16%
# Train Epoch: 0 [30848/60000 (51.41%)]	Batch Loss: 0.653		Batch Accuracy: 82.81%
# Train Epoch: 0 [30976/60000 (51.63%)]	Batch Loss: 0.353		Batch Accuracy: 92.19%
# Train Epoch: 0 [31104/60000 (51.84%)]	Batch Loss: 0.651		Batch Accuracy: 81.25%
# Train Epoch: 0 [31232/60000 (52.05%)]	Batch Loss: 0.456		Batch Accuracy: 83.59%
# Train Epoch: 0 [31360/60000 (52.27%)]	Batch Loss: 0.455		Batch Accuracy: 88.28%
# Train Epoch: 0 [31488/60000 (52.48%)]	Batch Loss: 0.810		Batch Accuracy: 77.34%
# Train Epoch: 0 [31616/60000 (52.69%)]	Batch Loss: 0.484		Batch Accuracy: 85.16%
# Train Epoch: 0 [31744/60000 (52.91%)]	Batch Loss: 0.478		Batch Accuracy: 85.94%
# Train Epoch: 0 [31872/60000 (53.12%)]	Batch Loss: 0.475		Batch Accuracy: 85.94%
# Train Epoch: 0 [32000/60000 (53.33%)]	Batch Loss: 0.526		Batch Accuracy: 83.59%
# Train Epoch: 0 [32128/60000 (53.55%)]	Batch Loss: 0.432		Batch Accuracy: 87.50%
# Train Epoch: 0 [32256/60000 (53.76%)]	Batch Loss: 0.713		Batch Accuracy: 82.03%
# Train Epoch: 0 [32384/60000 (53.97%)]	Batch Loss: 0.587		Batch Accuracy: 81.25%
# Train Epoch: 0 [32512/60000 (54.19%)]	Batch Loss: 0.469		Batch Accuracy: 82.81%
# Train Epoch: 0 [32640/60000 (54.40%)]	Batch Loss: 0.464		Batch Accuracy: 82.81%
# Train Epoch: 0 [32768/60000 (54.61%)]	Batch Loss: 0.445		Batch Accuracy: 85.94%
# Train Epoch: 0 [32896/60000 (54.83%)]	Batch Loss: 0.649		Batch Accuracy: 77.34%
# Train Epoch: 0 [33024/60000 (55.04%)]	Batch Loss: 0.480		Batch Accuracy: 82.81%
# Train Epoch: 0 [33152/60000 (55.25%)]	Batch Loss: 0.615		Batch Accuracy: 77.34%
# Train Epoch: 0 [33280/60000 (55.47%)]	Batch Loss: 0.451		Batch Accuracy: 84.38%
# Train Epoch: 0 [33408/60000 (55.68%)]	Batch Loss: 0.597		Batch Accuracy: 80.47%
# Train Epoch: 0 [33536/60000 (55.89%)]	Batch Loss: 0.409		Batch Accuracy: 89.06%
# Train Epoch: 0 [33664/60000 (56.11%)]	Batch Loss: 0.451		Batch Accuracy: 85.16%
# Train Epoch: 0 [33792/60000 (56.32%)]	Batch Loss: 0.679		Batch Accuracy: 78.91%
# Train Epoch: 0 [33920/60000 (56.53%)]	Batch Loss: 0.483		Batch Accuracy: 84.38%
# Train Epoch: 0 [34048/60000 (56.75%)]	Batch Loss: 0.489		Batch Accuracy: 83.59%
# Train Epoch: 0 [34176/60000 (56.96%)]	Batch Loss: 0.573		Batch Accuracy: 78.12%
# Train Epoch: 0 [34304/60000 (57.17%)]	Batch Loss: 0.703		Batch Accuracy: 75.00%
# Train Epoch: 0 [34432/60000 (57.39%)]	Batch Loss: 0.427		Batch Accuracy: 86.72%
# Train Epoch: 0 [34560/60000 (57.60%)]	Batch Loss: 0.657		Batch Accuracy: 82.03%
# Train Epoch: 0 [34688/60000 (57.81%)]	Batch Loss: 0.446		Batch Accuracy: 83.59%
# Train Epoch: 0 [34816/60000 (58.03%)]	Batch Loss: 0.345		Batch Accuracy: 90.62%
# Train Epoch: 0 [34944/60000 (58.24%)]	Batch Loss: 0.311		Batch Accuracy: 92.97%
# Train Epoch: 0 [35072/60000 (58.45%)]	Batch Loss: 0.566		Batch Accuracy: 80.47%
# Train Epoch: 0 [35200/60000 (58.67%)]	Batch Loss: 0.827		Batch Accuracy: 77.34%
# Train Epoch: 0 [35328/60000 (58.88%)]	Batch Loss: 0.635		Batch Accuracy: 78.91%
# Train Epoch: 0 [35456/60000 (59.09%)]	Batch Loss: 0.547		Batch Accuracy: 81.25%
# Train Epoch: 0 [35584/60000 (59.31%)]	Batch Loss: 0.514		Batch Accuracy: 84.38%
# Train Epoch: 0 [35712/60000 (59.52%)]	Batch Loss: 0.482		Batch Accuracy: 88.28%
# Train Epoch: 0 [35840/60000 (59.73%)]	Batch Loss: 0.528		Batch Accuracy: 85.16%
# Train Epoch: 0 [35968/60000 (59.95%)]	Batch Loss: 0.586		Batch Accuracy: 83.59%
# Train Epoch: 0 [36096/60000 (60.16%)]	Batch Loss: 0.610		Batch Accuracy: 85.94%
# Train Epoch: 0 [36224/60000 (60.37%)]	Batch Loss: 0.561		Batch Accuracy: 81.25%
# Train Epoch: 0 [36352/60000 (60.59%)]	Batch Loss: 0.391		Batch Accuracy: 87.50%
# Train Epoch: 0 [36480/60000 (60.80%)]	Batch Loss: 0.392		Batch Accuracy: 90.62%
# Train Epoch: 0 [36608/60000 (61.01%)]	Batch Loss: 0.404		Batch Accuracy: 89.06%
# Train Epoch: 0 [36736/60000 (61.23%)]	Batch Loss: 0.456		Batch Accuracy: 83.59%
# Train Epoch: 0 [36864/60000 (61.44%)]	Batch Loss: 0.357		Batch Accuracy: 89.84%
# Train Epoch: 0 [36992/60000 (61.65%)]	Batch Loss: 0.627		Batch Accuracy: 82.03%
# Train Epoch: 0 [37120/60000 (61.87%)]	Batch Loss: 0.545		Batch Accuracy: 85.16%
# Train Epoch: 0 [37248/60000 (62.08%)]	Batch Loss: 0.640		Batch Accuracy: 75.00%
# Train Epoch: 0 [37376/60000 (62.29%)]	Batch Loss: 0.516		Batch Accuracy: 85.94%
# Train Epoch: 0 [37504/60000 (62.51%)]	Batch Loss: 0.566		Batch Accuracy: 82.03%
# Train Epoch: 0 [37632/60000 (62.72%)]	Batch Loss: 0.499		Batch Accuracy: 83.59%
# Train Epoch: 0 [37760/60000 (62.93%)]	Batch Loss: 0.521		Batch Accuracy: 87.50%
# Train Epoch: 0 [37888/60000 (63.15%)]	Batch Loss: 0.725		Batch Accuracy: 82.03%
# Train Epoch: 0 [38016/60000 (63.36%)]	Batch Loss: 0.526		Batch Accuracy: 84.38%
# Train Epoch: 0 [38144/60000 (63.57%)]	Batch Loss: 0.564		Batch Accuracy: 84.38%
# Train Epoch: 0 [38272/60000 (63.79%)]	Batch Loss: 0.503		Batch Accuracy: 84.38%
# Train Epoch: 0 [38400/60000 (64.00%)]	Batch Loss: 0.396		Batch Accuracy: 89.84%
# Train Epoch: 0 [38528/60000 (64.21%)]	Batch Loss: 0.543		Batch Accuracy: 85.16%
# Train Epoch: 0 [38656/60000 (64.43%)]	Batch Loss: 0.555		Batch Accuracy: 84.38%
# Train Epoch: 0 [38784/60000 (64.64%)]	Batch Loss: 0.639		Batch Accuracy: 86.72%
# Train Epoch: 0 [38912/60000 (64.85%)]	Batch Loss: 0.565		Batch Accuracy: 82.81%
# Train Epoch: 0 [39040/60000 (65.07%)]	Batch Loss: 0.627		Batch Accuracy: 80.47%
# Train Epoch: 0 [39168/60000 (65.28%)]	Batch Loss: 0.654		Batch Accuracy: 82.03%
# Train Epoch: 0 [39296/60000 (65.49%)]	Batch Loss: 0.577		Batch Accuracy: 86.72%
# Train Epoch: 0 [39424/60000 (65.71%)]	Batch Loss: 0.476		Batch Accuracy: 86.72%
# Train Epoch: 0 [39552/60000 (65.92%)]	Batch Loss: 0.660		Batch Accuracy: 82.03%
# Train Epoch: 0 [39680/60000 (66.13%)]	Batch Loss: 0.400		Batch Accuracy: 87.50%
# Train Epoch: 0 [39808/60000 (66.35%)]	Batch Loss: 0.320		Batch Accuracy: 91.41%
# Train Epoch: 0 [39936/60000 (66.56%)]	Batch Loss: 0.453		Batch Accuracy: 85.94%
# Train Epoch: 0 [40064/60000 (66.77%)]	Batch Loss: 0.539		Batch Accuracy: 82.81%
# Train Epoch: 0 [40192/60000 (66.99%)]	Batch Loss: 0.499		Batch Accuracy: 85.94%
# Train Epoch: 0 [40320/60000 (67.20%)]	Batch Loss: 0.402		Batch Accuracy: 89.06%
# Train Epoch: 0 [40448/60000 (67.41%)]	Batch Loss: 0.359		Batch Accuracy: 89.06%
# Train Epoch: 0 [40576/60000 (67.63%)]	Batch Loss: 0.467		Batch Accuracy: 85.16%
# Train Epoch: 0 [40704/60000 (67.84%)]	Batch Loss: 0.438		Batch Accuracy: 87.50%
# Train Epoch: 0 [40832/60000 (68.05%)]	Batch Loss: 0.542		Batch Accuracy: 82.81%
# Train Epoch: 0 [40960/60000 (68.27%)]	Batch Loss: 0.545		Batch Accuracy: 87.50%
# Train Epoch: 0 [41088/60000 (68.48%)]	Batch Loss: 0.479		Batch Accuracy: 87.50%
# Train Epoch: 0 [41216/60000 (68.69%)]	Batch Loss: 0.475		Batch Accuracy: 87.50%
# Train Epoch: 0 [41344/60000 (68.91%)]	Batch Loss: 0.625		Batch Accuracy: 78.91%
# Train Epoch: 0 [41472/60000 (69.12%)]	Batch Loss: 0.500		Batch Accuracy: 83.59%
# Train Epoch: 0 [41600/60000 (69.33%)]	Batch Loss: 0.528		Batch Accuracy: 84.38%
# Train Epoch: 0 [41728/60000 (69.55%)]	Batch Loss: 0.390		Batch Accuracy: 89.06%
# Train Epoch: 0 [41856/60000 (69.76%)]	Batch Loss: 0.403		Batch Accuracy: 87.50%
# Train Epoch: 0 [41984/60000 (69.97%)]	Batch Loss: 0.348		Batch Accuracy: 89.06%
# Train Epoch: 0 [42112/60000 (70.19%)]	Batch Loss: 0.658		Batch Accuracy: 81.25%
# Train Epoch: 0 [42240/60000 (70.40%)]	Batch Loss: 0.628		Batch Accuracy: 79.69%
# Train Epoch: 0 [42368/60000 (70.61%)]	Batch Loss: 0.477		Batch Accuracy: 85.94%
# Train Epoch: 0 [42496/60000 (70.83%)]	Batch Loss: 0.483		Batch Accuracy: 85.16%
# Train Epoch: 0 [42624/60000 (71.04%)]	Batch Loss: 0.383		Batch Accuracy: 88.28%
# Train Epoch: 0 [42752/60000 (71.25%)]	Batch Loss: 0.424		Batch Accuracy: 86.72%
# Train Epoch: 0 [42880/60000 (71.47%)]	Batch Loss: 0.437		Batch Accuracy: 89.06%
# Train Epoch: 0 [43008/60000 (71.68%)]	Batch Loss: 0.370		Batch Accuracy: 90.62%
# Train Epoch: 0 [43136/60000 (71.89%)]	Batch Loss: 0.418		Batch Accuracy: 87.50%
# Train Epoch: 0 [43264/60000 (72.11%)]	Batch Loss: 0.484		Batch Accuracy: 82.81%
# Train Epoch: 0 [43392/60000 (72.32%)]	Batch Loss: 0.601		Batch Accuracy: 82.03%
# Train Epoch: 0 [43520/60000 (72.53%)]	Batch Loss: 0.483		Batch Accuracy: 82.81%
# Train Epoch: 0 [43648/60000 (72.75%)]	Batch Loss: 0.414		Batch Accuracy: 85.94%
# Train Epoch: 0 [43776/60000 (72.96%)]	Batch Loss: 0.343		Batch Accuracy: 89.84%
# Train Epoch: 0 [43904/60000 (73.17%)]	Batch Loss: 0.408		Batch Accuracy: 89.84%
# Train Epoch: 0 [44032/60000 (73.39%)]	Batch Loss: 0.450		Batch Accuracy: 89.06%
# Train Epoch: 0 [44160/60000 (73.60%)]	Batch Loss: 0.679		Batch Accuracy: 83.59%
# Train Epoch: 0 [44288/60000 (73.81%)]	Batch Loss: 0.685		Batch Accuracy: 80.47%
# Train Epoch: 0 [44416/60000 (74.03%)]	Batch Loss: 0.688		Batch Accuracy: 78.91%
# Train Epoch: 0 [44544/60000 (74.24%)]	Batch Loss: 0.449		Batch Accuracy: 86.72%
# Train Epoch: 0 [44672/60000 (74.45%)]	Batch Loss: 0.452		Batch Accuracy: 87.50%
# Train Epoch: 0 [44800/60000 (74.67%)]	Batch Loss: 0.339		Batch Accuracy: 90.62%
# Train Epoch: 0 [44928/60000 (74.88%)]	Batch Loss: 0.747		Batch Accuracy: 76.56%
# Train Epoch: 0 [45056/60000 (75.09%)]	Batch Loss: 0.580		Batch Accuracy: 82.81%
# Train Epoch: 0 [45184/60000 (75.31%)]	Batch Loss: 0.598		Batch Accuracy: 78.12%
# Train Epoch: 0 [45312/60000 (75.52%)]	Batch Loss: 0.484		Batch Accuracy: 88.28%
# Train Epoch: 0 [45440/60000 (75.73%)]	Batch Loss: 0.437		Batch Accuracy: 86.72%
# Train Epoch: 0 [45568/60000 (75.95%)]	Batch Loss: 0.427		Batch Accuracy: 87.50%
# Train Epoch: 0 [45696/60000 (76.16%)]	Batch Loss: 0.515		Batch Accuracy: 85.94%
# Train Epoch: 0 [45824/60000 (76.37%)]	Batch Loss: 0.614		Batch Accuracy: 83.59%
# Train Epoch: 0 [45952/60000 (76.59%)]	Batch Loss: 0.583		Batch Accuracy: 82.03%
# Train Epoch: 0 [46080/60000 (76.80%)]	Batch Loss: 0.335		Batch Accuracy: 89.06%
# Train Epoch: 0 [46208/60000 (77.01%)]	Batch Loss: 0.389		Batch Accuracy: 90.62%
# Train Epoch: 0 [46336/60000 (77.23%)]	Batch Loss: 0.430		Batch Accuracy: 85.16%
# Train Epoch: 0 [46464/60000 (77.44%)]	Batch Loss: 0.403		Batch Accuracy: 86.72%
# Train Epoch: 0 [46592/60000 (77.65%)]	Batch Loss: 0.516		Batch Accuracy: 80.47%
# Train Epoch: 0 [46720/60000 (77.87%)]	Batch Loss: 0.450		Batch Accuracy: 82.03%
# Train Epoch: 0 [46848/60000 (78.08%)]	Batch Loss: 0.661		Batch Accuracy: 84.38%
# Train Epoch: 0 [46976/60000 (78.29%)]	Batch Loss: 0.700		Batch Accuracy: 78.91%
# Train Epoch: 0 [47104/60000 (78.51%)]	Batch Loss: 0.443		Batch Accuracy: 85.16%
# Train Epoch: 0 [47232/60000 (78.72%)]	Batch Loss: 0.489		Batch Accuracy: 87.50%
# Train Epoch: 0 [47360/60000 (78.93%)]	Batch Loss: 0.296		Batch Accuracy: 92.19%
# Train Epoch: 0 [47488/60000 (79.15%)]	Batch Loss: 0.409		Batch Accuracy: 87.50%
# Train Epoch: 0 [47616/60000 (79.36%)]	Batch Loss: 0.465		Batch Accuracy: 84.38%
# Train Epoch: 0 [47744/60000 (79.57%)]	Batch Loss: 0.467		Batch Accuracy: 84.38%
# Train Epoch: 0 [47872/60000 (79.79%)]	Batch Loss: 0.494		Batch Accuracy: 85.16%
# Train Epoch: 0 [48000/60000 (80.00%)]	Batch Loss: 0.356		Batch Accuracy: 91.41%
# Train Epoch: 0 [48128/60000 (80.21%)]	Batch Loss: 0.630		Batch Accuracy: 82.03%
# Train Epoch: 0 [48256/60000 (80.43%)]	Batch Loss: 0.476		Batch Accuracy: 87.50%
# Train Epoch: 0 [48384/60000 (80.64%)]	Batch Loss: 0.540		Batch Accuracy: 82.03%
# Train Epoch: 0 [48512/60000 (80.85%)]	Batch Loss: 0.384		Batch Accuracy: 88.28%
# Train Epoch: 0 [48640/60000 (81.07%)]	Batch Loss: 0.404		Batch Accuracy: 89.06%
# Train Epoch: 0 [48768/60000 (81.28%)]	Batch Loss: 0.470		Batch Accuracy: 82.81%
# Train Epoch: 0 [48896/60000 (81.49%)]	Batch Loss: 0.485		Batch Accuracy: 83.59%
# Train Epoch: 0 [49024/60000 (81.71%)]	Batch Loss: 0.577		Batch Accuracy: 85.16%
# Train Epoch: 0 [49152/60000 (81.92%)]	Batch Loss: 0.631		Batch Accuracy: 82.81%
# Train Epoch: 0 [49280/60000 (82.13%)]	Batch Loss: 0.385		Batch Accuracy: 85.94%
# Train Epoch: 0 [49408/60000 (82.35%)]	Batch Loss: 0.546		Batch Accuracy: 82.81%
# Train Epoch: 0 [49536/60000 (82.56%)]	Batch Loss: 0.711		Batch Accuracy: 76.56%
# Train Epoch: 0 [49664/60000 (82.77%)]	Batch Loss: 0.675		Batch Accuracy: 85.16%
# Train Epoch: 0 [49792/60000 (82.99%)]	Batch Loss: 0.566		Batch Accuracy: 80.47%
# Train Epoch: 0 [49920/60000 (83.20%)]	Batch Loss: 0.838		Batch Accuracy: 80.47%
# Train Epoch: 0 [50048/60000 (83.41%)]	Batch Loss: 0.548		Batch Accuracy: 78.91%
# Train Epoch: 0 [50176/60000 (83.63%)]	Batch Loss: 0.604		Batch Accuracy: 82.03%
# Train Epoch: 0 [50304/60000 (83.84%)]	Batch Loss: 0.531		Batch Accuracy: 79.69%
# Train Epoch: 0 [50432/60000 (84.05%)]	Batch Loss: 0.468		Batch Accuracy: 88.28%
# Train Epoch: 0 [50560/60000 (84.27%)]	Batch Loss: 0.437		Batch Accuracy: 82.81%
# Train Epoch: 0 [50688/60000 (84.48%)]	Batch Loss: 0.472		Batch Accuracy: 84.38%
# Train Epoch: 0 [50816/60000 (84.69%)]	Batch Loss: 0.418		Batch Accuracy: 85.94%
# Train Epoch: 0 [50944/60000 (84.91%)]	Batch Loss: 0.692		Batch Accuracy: 78.91%
# Train Epoch: 0 [51072/60000 (85.12%)]	Batch Loss: 0.584		Batch Accuracy: 87.50%
# Train Epoch: 0 [51200/60000 (85.33%)]	Batch Loss: 0.437		Batch Accuracy: 82.81%
# Train Epoch: 0 [51328/60000 (85.55%)]	Batch Loss: 0.401		Batch Accuracy: 88.28%
# Train Epoch: 0 [51456/60000 (85.76%)]	Batch Loss: 0.425		Batch Accuracy: 85.16%
# Train Epoch: 0 [51584/60000 (85.97%)]	Batch Loss: 0.544		Batch Accuracy: 83.59%
# Train Epoch: 0 [51712/60000 (86.19%)]	Batch Loss: 0.442		Batch Accuracy: 87.50%
# Train Epoch: 0 [51840/60000 (86.40%)]	Batch Loss: 0.544		Batch Accuracy: 84.38%
# Train Epoch: 0 [51968/60000 (86.61%)]	Batch Loss: 0.420		Batch Accuracy: 85.94%
# Train Epoch: 0 [52096/60000 (86.83%)]	Batch Loss: 0.551		Batch Accuracy: 86.72%
# Train Epoch: 0 [52224/60000 (87.04%)]	Batch Loss: 0.508		Batch Accuracy: 84.38%
# Train Epoch: 0 [52352/60000 (87.25%)]	Batch Loss: 0.562		Batch Accuracy: 82.81%
# Train Epoch: 0 [52480/60000 (87.47%)]	Batch Loss: 0.513		Batch Accuracy: 78.91%
# Train Epoch: 0 [52608/60000 (87.68%)]	Batch Loss: 0.722		Batch Accuracy: 76.56%
# Train Epoch: 0 [52736/60000 (87.89%)]	Batch Loss: 0.602		Batch Accuracy: 82.81%
# Train Epoch: 0 [52864/60000 (88.11%)]	Batch Loss: 0.584		Batch Accuracy: 85.94%
# Train Epoch: 0 [52992/60000 (88.32%)]	Batch Loss: 0.775		Batch Accuracy: 76.56%
# Train Epoch: 0 [53120/60000 (88.53%)]	Batch Loss: 0.362		Batch Accuracy: 89.84%
# Train Epoch: 0 [53248/60000 (88.75%)]	Batch Loss: 0.447		Batch Accuracy: 85.16%
# Train Epoch: 0 [53376/60000 (88.96%)]	Batch Loss: 0.489		Batch Accuracy: 84.38%
# Train Epoch: 0 [53504/60000 (89.17%)]	Batch Loss: 0.278		Batch Accuracy: 92.97%
# Train Epoch: 0 [53632/60000 (89.39%)]	Batch Loss: 0.504		Batch Accuracy: 83.59%
# Train Epoch: 0 [53760/60000 (89.60%)]	Batch Loss: 0.444		Batch Accuracy: 82.03%
# Train Epoch: 0 [53888/60000 (89.81%)]	Batch Loss: 0.559		Batch Accuracy: 85.16%
# Train Epoch: 0 [54016/60000 (90.03%)]	Batch Loss: 0.488		Batch Accuracy: 82.81%
# Train Epoch: 0 [54144/60000 (90.24%)]	Batch Loss: 0.344		Batch Accuracy: 88.28%
# Train Epoch: 0 [54272/60000 (90.45%)]	Batch Loss: 0.208		Batch Accuracy: 93.75%
# Train Epoch: 0 [54400/60000 (90.67%)]	Batch Loss: 0.341		Batch Accuracy: 90.62%
# Train Epoch: 0 [54528/60000 (90.88%)]	Batch Loss: 0.519		Batch Accuracy: 85.16%
# Train Epoch: 0 [54656/60000 (91.09%)]	Batch Loss: 0.467		Batch Accuracy: 85.94%
# Train Epoch: 0 [54784/60000 (91.31%)]	Batch Loss: 0.387		Batch Accuracy: 90.62%
# Train Epoch: 0 [54912/60000 (91.52%)]	Batch Loss: 0.386		Batch Accuracy: 89.06%
# Train Epoch: 0 [55040/60000 (91.73%)]	Batch Loss: 0.359		Batch Accuracy: 89.06%
# Train Epoch: 0 [55168/60000 (91.95%)]	Batch Loss: 0.590		Batch Accuracy: 83.59%
# Train Epoch: 0 [55296/60000 (92.16%)]	Batch Loss: 0.421		Batch Accuracy: 83.59%
# Train Epoch: 0 [55424/60000 (92.37%)]	Batch Loss: 0.459		Batch Accuracy: 85.16%
# Train Epoch: 0 [55552/60000 (92.59%)]	Batch Loss: 0.485		Batch Accuracy: 83.59%
# Train Epoch: 0 [55680/60000 (92.80%)]	Batch Loss: 0.284		Batch Accuracy: 90.62%
# Train Epoch: 0 [55808/60000 (93.01%)]	Batch Loss: 0.534		Batch Accuracy: 82.81%
# Train Epoch: 0 [55936/60000 (93.23%)]	Batch Loss: 0.564		Batch Accuracy: 84.38%
# Train Epoch: 0 [56064/60000 (93.44%)]	Batch Loss: 0.419		Batch Accuracy: 86.72%
# Train Epoch: 0 [56192/60000 (93.65%)]	Batch Loss: 0.350		Batch Accuracy: 88.28%
# Train Epoch: 0 [56320/60000 (93.87%)]	Batch Loss: 0.389		Batch Accuracy: 93.75%
# Train Epoch: 0 [56448/60000 (94.08%)]	Batch Loss: 0.544		Batch Accuracy: 85.94%
# Train Epoch: 0 [56576/60000 (94.29%)]	Batch Loss: 0.443		Batch Accuracy: 87.50%
# Train Epoch: 0 [56704/60000 (94.51%)]	Batch Loss: 0.398		Batch Accuracy: 88.28%
# Train Epoch: 0 [56832/60000 (94.72%)]	Batch Loss: 0.406		Batch Accuracy: 88.28%
# Train Epoch: 0 [56960/60000 (94.93%)]	Batch Loss: 0.626		Batch Accuracy: 84.38%
# Train Epoch: 0 [57088/60000 (95.15%)]	Batch Loss: 0.670		Batch Accuracy: 82.03%
# Train Epoch: 0 [57216/60000 (95.36%)]	Batch Loss: 0.506		Batch Accuracy: 82.81%
# Train Epoch: 0 [57344/60000 (95.57%)]	Batch Loss: 0.460		Batch Accuracy: 85.16%
# Train Epoch: 0 [57472/60000 (95.79%)]	Batch Loss: 0.523		Batch Accuracy: 84.38%
# Train Epoch: 0 [57600/60000 (96.00%)]	Batch Loss: 0.518		Batch Accuracy: 83.59%
# Train Epoch: 0 [57728/60000 (96.21%)]	Batch Loss: 0.562		Batch Accuracy: 82.81%
# Train Epoch: 0 [57856/60000 (96.43%)]	Batch Loss: 0.497		Batch Accuracy: 85.94%
# Train Epoch: 0 [57984/60000 (96.64%)]	Batch Loss: 0.581		Batch Accuracy: 81.25%
# Train Epoch: 0 [58112/60000 (96.85%)]	Batch Loss: 0.535		Batch Accuracy: 84.38%
# Train Epoch: 0 [58240/60000 (97.07%)]	Batch Loss: 0.467		Batch Accuracy: 83.59%
# Train Epoch: 0 [58368/60000 (97.28%)]	Batch Loss: 0.502		Batch Accuracy: 80.47%
# Train Epoch: 0 [58496/60000 (97.49%)]	Batch Loss: 0.413		Batch Accuracy: 88.28%
# Train Epoch: 0 [58624/60000 (97.71%)]	Batch Loss: 0.428		Batch Accuracy: 85.94%
# Train Epoch: 0 [58752/60000 (97.92%)]	Batch Loss: 0.280		Batch Accuracy: 91.41%
# Train Epoch: 0 [58880/60000 (98.13%)]	Batch Loss: 0.423		Batch Accuracy: 87.50%
# Train Epoch: 0 [59008/60000 (98.35%)]	Batch Loss: 0.495		Batch Accuracy: 84.38%
# Train Epoch: 0 [59136/60000 (98.56%)]	Batch Loss: 0.296		Batch Accuracy: 87.50%
# Train Epoch: 0 [59264/60000 (98.77%)]	Batch Loss: 0.451		Batch Accuracy: 88.28%
# Train Epoch: 0 [59392/60000 (98.99%)]	Batch Loss: 0.415		Batch Accuracy: 88.28%
# Train Epoch: 0 [59520/60000 (99.20%)]	Batch Loss: 0.742		Batch Accuracy: 80.47%
# Train Epoch: 0 [59648/60000 (99.41%)]	Batch Loss: 0.657		Batch Accuracy: 79.69%
# Train Epoch: 0 [59776/60000 (99.63%)]	Batch Loss: 0.607		Batch Accuracy: 85.94%
# Train Epoch: 0 [59904/60000 (99.84%)]	Batch Loss: 0.389		Batch Accuracy: 90.62%
# Train Epoch: 0 [60000/60000 (100.00%)]	Batch Loss: 0.480		Batch Accuracy: 82.29%
# Train Epoch 0| Loss: 0.671	Accuracy: 80.61%
# Test Epoch 0| Loss: 0.468	Accuracy: 85.85%	Best Accuracy: 85.85
# Train Epoch: 1 [128/60000 (0.21%)]	Batch Loss: 0.455		Batch Accuracy: 86.72%
# Train Epoch: 1 [256/60000 (0.43%)]	Batch Loss: 0.564		Batch Accuracy: 82.03%
# Train Epoch: 1 [384/60000 (0.64%)]	Batch Loss: 0.385		Batch Accuracy: 86.72%
# Train Epoch: 1 [512/60000 (0.85%)]	Batch Loss: 0.387		Batch Accuracy: 85.94%
# Train Epoch: 1 [640/60000 (1.07%)]	Batch Loss: 0.369		Batch Accuracy: 90.62%
# Train Epoch: 1 [768/60000 (1.28%)]	Batch Loss: 0.399		Batch Accuracy: 90.62%
# Train Epoch: 1 [896/60000 (1.49%)]	Batch Loss: 0.518		Batch Accuracy: 82.81%
# Train Epoch: 1 [1024/60000 (1.71%)]	Batch Loss: 0.410		Batch Accuracy: 84.38%
# Train Epoch: 1 [1152/60000 (1.92%)]	Batch Loss: 0.560		Batch Accuracy: 81.25%
# Train Epoch: 1 [1280/60000 (2.13%)]	Batch Loss: 0.332		Batch Accuracy: 87.50%
# Train Epoch: 1 [1408/60000 (2.35%)]	Batch Loss: 0.317		Batch Accuracy: 89.84%
# Train Epoch: 1 [1536/60000 (2.56%)]	Batch Loss: 0.491		Batch Accuracy: 87.50%
# Train Epoch: 1 [1664/60000 (2.77%)]	Batch Loss: 0.436		Batch Accuracy: 89.84%
# Train Epoch: 1 [1792/60000 (2.99%)]	Batch Loss: 0.388		Batch Accuracy: 85.94%
# Train Epoch: 1 [1920/60000 (3.20%)]	Batch Loss: 0.403		Batch Accuracy: 90.62%
# Train Epoch: 1 [2048/60000 (3.41%)]	Batch Loss: 0.380		Batch Accuracy: 89.84%
# Train Epoch: 1 [2176/60000 (3.63%)]	Batch Loss: 0.481		Batch Accuracy: 89.84%
# Train Epoch: 1 [2304/60000 (3.84%)]	Batch Loss: 0.358		Batch Accuracy: 88.28%
# Train Epoch: 1 [2432/60000 (4.05%)]	Batch Loss: 0.431		Batch Accuracy: 86.72%
# Train Epoch: 1 [2560/60000 (4.27%)]	Batch Loss: 0.694		Batch Accuracy: 80.47%
# Train Epoch: 1 [2688/60000 (4.48%)]	Batch Loss: 0.323		Batch Accuracy: 92.19%
# Train Epoch: 1 [2816/60000 (4.69%)]	Batch Loss: 0.244		Batch Accuracy: 92.97%
# Train Epoch: 1 [2944/60000 (4.91%)]	Batch Loss: 0.381		Batch Accuracy: 91.41%
# Train Epoch: 1 [3072/60000 (5.12%)]	Batch Loss: 0.415		Batch Accuracy: 86.72%
# Train Epoch: 1 [3200/60000 (5.33%)]	Batch Loss: 0.305		Batch Accuracy: 92.19%
# Train Epoch: 1 [3328/60000 (5.55%)]	Batch Loss: 0.464		Batch Accuracy: 87.50%
# Train Epoch: 1 [3456/60000 (5.76%)]	Batch Loss: 0.410		Batch Accuracy: 88.28%
# Train Epoch: 1 [3584/60000 (5.97%)]	Batch Loss: 0.485		Batch Accuracy: 85.16%
# Train Epoch: 1 [3712/60000 (6.19%)]	Batch Loss: 0.568		Batch Accuracy: 84.38%
# Train Epoch: 1 [3840/60000 (6.40%)]	Batch Loss: 0.573		Batch Accuracy: 80.47%
# Train Epoch: 1 [3968/60000 (6.61%)]	Batch Loss: 0.558		Batch Accuracy: 79.69%
# Train Epoch: 1 [4096/60000 (6.83%)]	Batch Loss: 0.529		Batch Accuracy: 85.16%
# Train Epoch: 1 [4224/60000 (7.04%)]	Batch Loss: 0.417		Batch Accuracy: 89.06%
# Train Epoch: 1 [4352/60000 (7.25%)]	Batch Loss: 0.514		Batch Accuracy: 85.94%
# Train Epoch: 1 [4480/60000 (7.47%)]	Batch Loss: 0.604		Batch Accuracy: 81.25%
# Train Epoch: 1 [4608/60000 (7.68%)]	Batch Loss: 0.496		Batch Accuracy: 88.28%
# Train Epoch: 1 [4736/60000 (7.89%)]	Batch Loss: 0.468		Batch Accuracy: 85.16%
# Train Epoch: 1 [4864/60000 (8.11%)]	Batch Loss: 0.440		Batch Accuracy: 86.72%
# Train Epoch: 1 [4992/60000 (8.32%)]	Batch Loss: 0.544		Batch Accuracy: 84.38%
# Train Epoch: 1 [5120/60000 (8.53%)]	Batch Loss: 0.332		Batch Accuracy: 88.28%
# Train Epoch: 1 [5248/60000 (8.75%)]	Batch Loss: 0.456		Batch Accuracy: 84.38%
# Train Epoch: 1 [5376/60000 (8.96%)]	Batch Loss: 0.443		Batch Accuracy: 84.38%
# Train Epoch: 1 [5504/60000 (9.17%)]	Batch Loss: 0.525		Batch Accuracy: 82.03%
# Train Epoch: 1 [5632/60000 (9.39%)]	Batch Loss: 0.724		Batch Accuracy: 79.69%
# Train Epoch: 1 [5760/60000 (9.60%)]	Batch Loss: 0.635		Batch Accuracy: 78.12%
# Train Epoch: 1 [5888/60000 (9.81%)]	Batch Loss: 0.481		Batch Accuracy: 85.16%
# Train Epoch: 1 [6016/60000 (10.03%)]	Batch Loss: 0.545		Batch Accuracy: 84.38%
# Train Epoch: 1 [6144/60000 (10.24%)]	Batch Loss: 0.295		Batch Accuracy: 93.75%
# Train Epoch: 1 [6272/60000 (10.45%)]	Batch Loss: 0.379		Batch Accuracy: 89.06%
# Train Epoch: 1 [6400/60000 (10.67%)]	Batch Loss: 0.584		Batch Accuracy: 85.16%
# Train Epoch: 1 [6528/60000 (10.88%)]	Batch Loss: 0.387		Batch Accuracy: 85.94%
# Train Epoch: 1 [6656/60000 (11.09%)]	Batch Loss: 0.406		Batch Accuracy: 88.28%
# Train Epoch: 1 [6784/60000 (11.31%)]	Batch Loss: 0.512		Batch Accuracy: 83.59%
# Train Epoch: 1 [6912/60000 (11.52%)]	Batch Loss: 0.267		Batch Accuracy: 92.19%
# Train Epoch: 1 [7040/60000 (11.73%)]	Batch Loss: 0.371		Batch Accuracy: 88.28%
# Train Epoch: 1 [7168/60000 (11.95%)]	Batch Loss: 0.505		Batch Accuracy: 86.72%
# Train Epoch: 1 [7296/60000 (12.16%)]	Batch Loss: 0.372		Batch Accuracy: 86.72%
# Train Epoch: 1 [7424/60000 (12.37%)]	Batch Loss: 0.346		Batch Accuracy: 89.06%
# Train Epoch: 1 [7552/60000 (12.59%)]	Batch Loss: 0.349		Batch Accuracy: 88.28%
# Train Epoch: 1 [7680/60000 (12.80%)]	Batch Loss: 0.432		Batch Accuracy: 87.50%
# Train Epoch: 1 [7808/60000 (13.01%)]	Batch Loss: 0.334		Batch Accuracy: 85.94%
# Train Epoch: 1 [7936/60000 (13.23%)]	Batch Loss: 0.354		Batch Accuracy: 89.06%
# Train Epoch: 1 [8064/60000 (13.44%)]	Batch Loss: 0.361		Batch Accuracy: 90.62%
# Train Epoch: 1 [8192/60000 (13.65%)]	Batch Loss: 0.321		Batch Accuracy: 89.06%
# Train Epoch: 1 [8320/60000 (13.87%)]	Batch Loss: 0.417		Batch Accuracy: 83.59%
# Train Epoch: 1 [8448/60000 (14.08%)]	Batch Loss: 0.467		Batch Accuracy: 88.28%
# Train Epoch: 1 [8576/60000 (14.29%)]	Batch Loss: 0.473		Batch Accuracy: 85.16%
# Train Epoch: 1 [8704/60000 (14.51%)]	Batch Loss: 0.496		Batch Accuracy: 82.03%
# Train Epoch: 1 [8832/60000 (14.72%)]	Batch Loss: 0.447		Batch Accuracy: 89.06%
# Train Epoch: 1 [8960/60000 (14.93%)]	Batch Loss: 0.564		Batch Accuracy: 79.69%
# Train Epoch: 1 [9088/60000 (15.15%)]	Batch Loss: 0.452		Batch Accuracy: 84.38%
# Train Epoch: 1 [9216/60000 (15.36%)]	Batch Loss: 0.444		Batch Accuracy: 85.94%
# Train Epoch: 1 [9344/60000 (15.57%)]	Batch Loss: 0.590		Batch Accuracy: 82.81%
# Train Epoch: 1 [9472/60000 (15.79%)]	Batch Loss: 0.573		Batch Accuracy: 85.16%
# Train Epoch: 1 [9600/60000 (16.00%)]	Batch Loss: 0.379		Batch Accuracy: 89.06%
# Train Epoch: 1 [9728/60000 (16.21%)]	Batch Loss: 0.556		Batch Accuracy: 81.25%
# Train Epoch: 1 [9856/60000 (16.43%)]	Batch Loss: 0.557		Batch Accuracy: 79.69%
# Train Epoch: 1 [9984/60000 (16.64%)]	Batch Loss: 0.325		Batch Accuracy: 89.06%
# Train Epoch: 1 [10112/60000 (16.85%)]	Batch Loss: 0.499		Batch Accuracy: 81.25%
# Train Epoch: 1 [10240/60000 (17.07%)]	Batch Loss: 0.579		Batch Accuracy: 88.28%
# Train Epoch: 1 [10368/60000 (17.28%)]	Batch Loss: 0.537		Batch Accuracy: 87.50%
# Train Epoch: 1 [10496/60000 (17.49%)]	Batch Loss: 0.580		Batch Accuracy: 85.94%
# Train Epoch: 1 [10624/60000 (17.71%)]	Batch Loss: 0.383		Batch Accuracy: 87.50%
# Train Epoch: 1 [10752/60000 (17.92%)]	Batch Loss: 0.524		Batch Accuracy: 85.94%
# Train Epoch: 1 [10880/60000 (18.13%)]	Batch Loss: 0.450		Batch Accuracy: 85.94%
# Train Epoch: 1 [11008/60000 (18.35%)]	Batch Loss: 0.544		Batch Accuracy: 80.47%
# Train Epoch: 1 [11136/60000 (18.56%)]	Batch Loss: 0.416		Batch Accuracy: 87.50%
# Train Epoch: 1 [11264/60000 (18.77%)]	Batch Loss: 0.406		Batch Accuracy: 85.94%
# Train Epoch: 1 [11392/60000 (18.99%)]	Batch Loss: 0.612		Batch Accuracy: 83.59%
# Train Epoch: 1 [11520/60000 (19.20%)]	Batch Loss: 0.330		Batch Accuracy: 90.62%
# Train Epoch: 1 [11648/60000 (19.41%)]	Batch Loss: 0.523		Batch Accuracy: 84.38%
# Train Epoch: 1 [11776/60000 (19.63%)]	Batch Loss: 0.269		Batch Accuracy: 89.84%
# Train Epoch: 1 [11904/60000 (19.84%)]	Batch Loss: 0.598		Batch Accuracy: 85.94%
# Train Epoch: 1 [12032/60000 (20.05%)]	Batch Loss: 0.445		Batch Accuracy: 85.94%
# Train Epoch: 1 [12160/60000 (20.27%)]	Batch Loss: 0.578		Batch Accuracy: 88.28%
# Train Epoch: 1 [12288/60000 (20.48%)]	Batch Loss: 0.386		Batch Accuracy: 88.28%
# Train Epoch: 1 [12416/60000 (20.69%)]	Batch Loss: 0.527		Batch Accuracy: 86.72%
# Train Epoch: 1 [12544/60000 (20.91%)]	Batch Loss: 0.687		Batch Accuracy: 80.47%
# Train Epoch: 1 [12672/60000 (21.12%)]	Batch Loss: 0.429		Batch Accuracy: 87.50%
# Train Epoch: 1 [12800/60000 (21.33%)]	Batch Loss: 0.418		Batch Accuracy: 85.94%
# Train Epoch: 1 [12928/60000 (21.55%)]	Batch Loss: 0.510		Batch Accuracy: 84.38%
# Train Epoch: 1 [13056/60000 (21.76%)]	Batch Loss: 0.501		Batch Accuracy: 85.94%
# Train Epoch: 1 [13184/60000 (21.97%)]	Batch Loss: 0.428		Batch Accuracy: 91.41%
# Train Epoch: 1 [13312/60000 (22.19%)]	Batch Loss: 0.512		Batch Accuracy: 85.94%
# Train Epoch: 1 [13440/60000 (22.40%)]	Batch Loss: 0.494		Batch Accuracy: 88.28%
# Train Epoch: 1 [13568/60000 (22.61%)]	Batch Loss: 0.477		Batch Accuracy: 87.50%
# Train Epoch: 1 [13696/60000 (22.83%)]	Batch Loss: 0.465		Batch Accuracy: 85.16%
# Train Epoch: 1 [13824/60000 (23.04%)]	Batch Loss: 0.508		Batch Accuracy: 85.16%
# Train Epoch: 1 [13952/60000 (23.25%)]	Batch Loss: 0.399		Batch Accuracy: 88.28%
# Train Epoch: 1 [14080/60000 (23.47%)]	Batch Loss: 0.331		Batch Accuracy: 92.19%
# Train Epoch: 1 [14208/60000 (23.68%)]	Batch Loss: 0.379		Batch Accuracy: 88.28%
# Train Epoch: 1 [14336/60000 (23.89%)]	Batch Loss: 0.342		Batch Accuracy: 91.41%
# Train Epoch: 1 [14464/60000 (24.11%)]	Batch Loss: 0.249		Batch Accuracy: 92.97%
# Train Epoch: 1 [14592/60000 (24.32%)]	Batch Loss: 0.468		Batch Accuracy: 78.91%
# Train Epoch: 1 [14720/60000 (24.53%)]	Batch Loss: 0.338		Batch Accuracy: 91.41%
# Train Epoch: 1 [14848/60000 (24.75%)]	Batch Loss: 0.482		Batch Accuracy: 86.72%
# Train Epoch: 1 [14976/60000 (24.96%)]	Batch Loss: 0.400		Batch Accuracy: 85.94%
# Train Epoch: 1 [15104/60000 (25.17%)]	Batch Loss: 0.307		Batch Accuracy: 90.62%
# Train Epoch: 1 [15232/60000 (25.39%)]	Batch Loss: 0.439		Batch Accuracy: 86.72%
# Train Epoch: 1 [15360/60000 (25.60%)]	Batch Loss: 0.310		Batch Accuracy: 91.41%
# Train Epoch: 1 [15488/60000 (25.81%)]	Batch Loss: 0.457		Batch Accuracy: 86.72%
# Train Epoch: 1 [15616/60000 (26.03%)]	Batch Loss: 0.515		Batch Accuracy: 84.38%
# Train Epoch: 1 [15744/60000 (26.24%)]	Batch Loss: 0.373		Batch Accuracy: 85.94%
# Train Epoch: 1 [15872/60000 (26.45%)]	Batch Loss: 0.476		Batch Accuracy: 86.72%
# Train Epoch: 1 [16000/60000 (26.67%)]	Batch Loss: 0.443		Batch Accuracy: 84.38%
# Train Epoch: 1 [16128/60000 (26.88%)]	Batch Loss: 0.290		Batch Accuracy: 91.41%
# Train Epoch: 1 [16256/60000 (27.09%)]	Batch Loss: 0.385		Batch Accuracy: 89.06%
# Train Epoch: 1 [16384/60000 (27.31%)]	Batch Loss: 0.628		Batch Accuracy: 80.47%
# Train Epoch: 1 [16512/60000 (27.52%)]	Batch Loss: 0.494		Batch Accuracy: 84.38%
# Train Epoch: 1 [16640/60000 (27.73%)]	Batch Loss: 0.509		Batch Accuracy: 83.59%
# Train Epoch: 1 [16768/60000 (27.95%)]	Batch Loss: 0.299		Batch Accuracy: 91.41%
# Train Epoch: 1 [16896/60000 (28.16%)]	Batch Loss: 0.450		Batch Accuracy: 84.38%
# ...
# Train Epoch: 4 [17024/60000 (28.37%)]	Batch Loss: 0.287		Batch Accuracy: 89.84%
# Train Epoch: 4 [17152/60000 (28.59%)]	Batch Loss: 0.203		Batch Accuracy: 92.97%
# Train Epoch: 4 [17280/60000 (28.80%)]	Batch Loss: 0.353		Batch Accuracy: 88.28%
# Train Epoch: 4 [17408/60000 (29.01%)]	Batch Loss: 0.393		Batch Accuracy: 89.84%
# Train Epoch: 4 [17536/60000 (29.23%)]	Batch Loss: 0.341		Batch Accuracy: 89.06%
# Train Epoch: 4 [17664/60000 (29.44%)]	Batch Loss: 0.267		Batch Accuracy: 92.19%
# Train Epoch: 4 [17792/60000 (29.65%)]	Batch Loss: 0.248		Batch Accuracy: 92.19%
# Train Epoch: 4 [17920/60000 (29.87%)]	Batch Loss: 0.374		Batch Accuracy: 85.94%
# Train Epoch: 4 [18048/60000 (30.08%)]	Batch Loss: 0.376		Batch Accuracy: 87.50%
# Train Epoch: 4 [18176/60000 (30.29%)]	Batch Loss: 0.182		Batch Accuracy: 93.75%
# Train Epoch: 4 [18304/60000 (30.51%)]	Batch Loss: 0.344		Batch Accuracy: 84.38%
# Train Epoch: 4 [18432/60000 (30.72%)]	Batch Loss: 0.387		Batch Accuracy: 92.19%
# Train Epoch: 4 [18560/60000 (30.93%)]	Batch Loss: 0.257		Batch Accuracy: 94.53%
# Train Epoch: 4 [18688/60000 (31.15%)]	Batch Loss: 0.275		Batch Accuracy: 91.41%
# Train Epoch: 4 [18816/60000 (31.36%)]	Batch Loss: 0.267		Batch Accuracy: 91.41%
# Train Epoch: 4 [18944/60000 (31.57%)]	Batch Loss: 0.221		Batch Accuracy: 93.75%
# Train Epoch: 4 [19072/60000 (31.79%)]	Batch Loss: 0.193		Batch Accuracy: 95.31%
# Train Epoch: 4 [19200/60000 (32.00%)]	Batch Loss: 0.199		Batch Accuracy: 96.09%
# Train Epoch: 4 [19328/60000 (32.21%)]	Batch Loss: 0.462		Batch Accuracy: 85.94%
# Train Epoch: 4 [19456/60000 (32.43%)]	Batch Loss: 0.372		Batch Accuracy: 86.72%
# Train Epoch: 4 [19584/60000 (32.64%)]	Batch Loss: 0.174		Batch Accuracy: 95.31%
# Train Epoch: 4 [19712/60000 (32.85%)]	Batch Loss: 0.171		Batch Accuracy: 93.75%
# Train Epoch: 4 [19840/60000 (33.07%)]	Batch Loss: 0.452		Batch Accuracy: 88.28%
# Train Epoch: 4 [19968/60000 (33.28%)]	Batch Loss: 0.260		Batch Accuracy: 89.06%
# Train Epoch: 4 [20096/60000 (33.49%)]	Batch Loss: 0.440		Batch Accuracy: 88.28%
# Train Epoch: 4 [20224/60000 (33.71%)]	Batch Loss: 0.201		Batch Accuracy: 92.19%
# Train Epoch: 4 [20352/60000 (33.92%)]	Batch Loss: 0.308		Batch Accuracy: 89.84%
# Train Epoch: 4 [20480/60000 (34.13%)]	Batch Loss: 0.238		Batch Accuracy: 92.97%
# Train Epoch: 4 [20608/60000 (34.35%)]	Batch Loss: 0.188		Batch Accuracy: 94.53%
# Train Epoch: 4 [20736/60000 (34.56%)]	Batch Loss: 0.187		Batch Accuracy: 96.09%
# Train Epoch: 4 [20864/60000 (34.77%)]	Batch Loss: 0.333		Batch Accuracy: 89.84%
# Train Epoch: 4 [20992/60000 (34.99%)]	Batch Loss: 0.141		Batch Accuracy: 96.88%
# Train Epoch: 4 [21120/60000 (35.20%)]	Batch Loss: 0.266		Batch Accuracy: 91.41%
# Train Epoch: 4 [21248/60000 (35.41%)]	Batch Loss: 0.209		Batch Accuracy: 92.19%
# Train Epoch: 4 [21376/60000 (35.63%)]	Batch Loss: 0.345		Batch Accuracy: 88.28%
# Train Epoch: 4 [21504/60000 (35.84%)]	Batch Loss: 0.242		Batch Accuracy: 92.19%
# Train Epoch: 4 [21632/60000 (36.05%)]	Batch Loss: 0.292		Batch Accuracy: 91.41%
# Train Epoch: 4 [21760/60000 (36.27%)]	Batch Loss: 0.325		Batch Accuracy: 90.62%
# Train Epoch: 4 [21888/60000 (36.48%)]	Batch Loss: 0.352		Batch Accuracy: 89.06%
# Train Epoch: 4 [22016/60000 (36.69%)]	Batch Loss: 0.434		Batch Accuracy: 86.72%
# Train Epoch: 4 [22144/60000 (36.91%)]	Batch Loss: 0.205		Batch Accuracy: 95.31%
# Train Epoch: 4 [22272/60000 (37.12%)]	Batch Loss: 0.399		Batch Accuracy: 86.72%
# Train Epoch: 4 [22400/60000 (37.33%)]	Batch Loss: 0.306		Batch Accuracy: 89.06%
# Train Epoch: 4 [22528/60000 (37.55%)]	Batch Loss: 0.236		Batch Accuracy: 91.41%
# Train Epoch: 4 [22656/60000 (37.76%)]	Batch Loss: 0.192		Batch Accuracy: 95.31%
# Train Epoch: 4 [22784/60000 (37.97%)]	Batch Loss: 0.312		Batch Accuracy: 89.06%
# Train Epoch: 4 [22912/60000 (38.19%)]	Batch Loss: 0.271		Batch Accuracy: 94.53%
# Train Epoch: 4 [23040/60000 (38.40%)]	Batch Loss: 0.130		Batch Accuracy: 96.09%
# Train Epoch: 4 [23168/60000 (38.61%)]	Batch Loss: 0.303		Batch Accuracy: 92.19%
# Train Epoch: 4 [23296/60000 (38.83%)]	Batch Loss: 0.311		Batch Accuracy: 90.62%
# Train Epoch: 4 [23424/60000 (39.04%)]	Batch Loss: 0.354		Batch Accuracy: 88.28%
# Train Epoch: 4 [23552/60000 (39.25%)]	Batch Loss: 0.146		Batch Accuracy: 96.09%
# Train Epoch: 4 [23680/60000 (39.47%)]	Batch Loss: 0.305		Batch Accuracy: 85.94%
# Train Epoch: 4 [23808/60000 (39.68%)]	Batch Loss: 0.304		Batch Accuracy: 91.41%
# Train Epoch: 4 [23936/60000 (39.89%)]	Batch Loss: 0.238		Batch Accuracy: 92.19%
# Train Epoch: 4 [24064/60000 (40.11%)]	Batch Loss: 0.359		Batch Accuracy: 88.28%
# Train Epoch: 4 [24192/60000 (40.32%)]	Batch Loss: 0.320		Batch Accuracy: 87.50%
# Train Epoch: 4 [24320/60000 (40.53%)]	Batch Loss: 0.354		Batch Accuracy: 89.06%
# Train Epoch: 4 [24448/60000 (40.75%)]	Batch Loss: 0.197		Batch Accuracy: 96.09%
# Train Epoch: 4 [24576/60000 (40.96%)]	Batch Loss: 0.196		Batch Accuracy: 94.53%
# Train Epoch: 4 [24704/60000 (41.17%)]	Batch Loss: 0.262		Batch Accuracy: 91.41%
# Train Epoch: 4 [24832/60000 (41.39%)]	Batch Loss: 0.303		Batch Accuracy: 92.19%
# Train Epoch: 4 [24960/60000 (41.60%)]	Batch Loss: 0.190		Batch Accuracy: 95.31%
# Train Epoch: 4 [25088/60000 (41.81%)]	Batch Loss: 0.224		Batch Accuracy: 92.97%
# Train Epoch: 4 [25216/60000 (42.03%)]	Batch Loss: 0.302		Batch Accuracy: 90.62%
# Train Epoch: 4 [25344/60000 (42.24%)]	Batch Loss: 0.190		Batch Accuracy: 94.53%
# Train Epoch: 4 [25472/60000 (42.45%)]	Batch Loss: 0.323		Batch Accuracy: 88.28%
# Train Epoch: 4 [25600/60000 (42.67%)]	Batch Loss: 0.356		Batch Accuracy: 89.84%
# Train Epoch: 4 [25728/60000 (42.88%)]	Batch Loss: 0.243		Batch Accuracy: 93.75%
# Train Epoch: 4 [25856/60000 (43.09%)]	Batch Loss: 0.221		Batch Accuracy: 92.97%
# Train Epoch: 4 [25984/60000 (43.31%)]	Batch Loss: 0.257		Batch Accuracy: 91.41%
# Train Epoch: 4 [26112/60000 (43.52%)]	Batch Loss: 0.172		Batch Accuracy: 95.31%
# Train Epoch: 4 [26240/60000 (43.73%)]	Batch Loss: 0.208		Batch Accuracy: 94.53%
# Train Epoch: 4 [26368/60000 (43.95%)]	Batch Loss: 0.363		Batch Accuracy: 89.06%
# Train Epoch: 4 [26496/60000 (44.16%)]	Batch Loss: 0.276		Batch Accuracy: 92.19%
# Train Epoch: 4 [26624/60000 (44.37%)]	Batch Loss: 0.117		Batch Accuracy: 98.44%
# Train Epoch: 4 [26752/60000 (44.59%)]	Batch Loss: 0.297		Batch Accuracy: 92.19%
# Train Epoch: 4 [26880/60000 (44.80%)]	Batch Loss: 0.229		Batch Accuracy: 96.09%
# Train Epoch: 4 [27008/60000 (45.01%)]	Batch Loss: 0.303		Batch Accuracy: 88.28%
# Train Epoch: 4 [27136/60000 (45.23%)]	Batch Loss: 0.392		Batch Accuracy: 90.62%
# Train Epoch: 4 [27264/60000 (45.44%)]	Batch Loss: 0.339		Batch Accuracy: 91.41%
# Train Epoch: 4 [27392/60000 (45.65%)]	Batch Loss: 0.243		Batch Accuracy: 90.62%
# Train Epoch: 4 [27520/60000 (45.87%)]	Batch Loss: 0.247		Batch Accuracy: 92.19%
# Train Epoch: 4 [27648/60000 (46.08%)]	Batch Loss: 0.265		Batch Accuracy: 92.19%
# Train Epoch: 4 [27776/60000 (46.29%)]	Batch Loss: 0.209		Batch Accuracy: 92.97%
# Train Epoch: 4 [27904/60000 (46.51%)]	Batch Loss: 0.379		Batch Accuracy: 87.50%
# Train Epoch: 4 [28032/60000 (46.72%)]	Batch Loss: 0.350		Batch Accuracy: 92.97%
# Train Epoch: 4 [28160/60000 (46.93%)]	Batch Loss: 0.198		Batch Accuracy: 92.19%
# Train Epoch: 4 [28288/60000 (47.15%)]	Batch Loss: 0.241		Batch Accuracy: 92.19%
# Train Epoch: 4 [28416/60000 (47.36%)]	Batch Loss: 0.277		Batch Accuracy: 92.19%
# Train Epoch: 4 [28544/60000 (47.57%)]	Batch Loss: 0.212		Batch Accuracy: 92.97%
# Train Epoch: 4 [28672/60000 (47.79%)]	Batch Loss: 0.139		Batch Accuracy: 95.31%
# Train Epoch: 4 [28800/60000 (48.00%)]	Batch Loss: 0.309		Batch Accuracy: 90.62%
# Train Epoch: 4 [28928/60000 (48.21%)]	Batch Loss: 0.218		Batch Accuracy: 90.62%
# Train Epoch: 4 [29056/60000 (48.43%)]	Batch Loss: 0.227		Batch Accuracy: 92.97%
# Train Epoch: 4 [29184/60000 (48.64%)]	Batch Loss: 0.267		Batch Accuracy: 90.62%
# Train Epoch: 4 [29312/60000 (48.85%)]	Batch Loss: 0.204		Batch Accuracy: 93.75%
# Train Epoch: 4 [29440/60000 (49.07%)]	Batch Loss: 0.341		Batch Accuracy: 91.41%
# Train Epoch: 4 [29568/60000 (49.28%)]	Batch Loss: 0.240		Batch Accuracy: 92.97%
# Train Epoch: 4 [29696/60000 (49.49%)]	Batch Loss: 0.201		Batch Accuracy: 93.75%
# Train Epoch: 4 [29824/60000 (49.71%)]	Batch Loss: 0.233		Batch Accuracy: 93.75%
# Train Epoch: 4 [29952/60000 (49.92%)]	Batch Loss: 0.314		Batch Accuracy: 89.06%
# Train Epoch: 4 [30080/60000 (50.13%)]	Batch Loss: 0.327		Batch Accuracy: 90.62%
# Train Epoch: 4 [30208/60000 (50.35%)]	Batch Loss: 0.276		Batch Accuracy: 92.97%
# Train Epoch: 4 [30336/60000 (50.56%)]	Batch Loss: 0.246		Batch Accuracy: 92.97%
# Train Epoch: 4 [30464/60000 (50.77%)]	Batch Loss: 0.174		Batch Accuracy: 94.53%
# Train Epoch: 4 [30592/60000 (50.99%)]	Batch Loss: 0.349		Batch Accuracy: 89.06%
# Train Epoch: 4 [30720/60000 (51.20%)]	Batch Loss: 0.209		Batch Accuracy: 94.53%
# Train Epoch: 4 [30848/60000 (51.41%)]	Batch Loss: 0.182		Batch Accuracy: 93.75%
# Train Epoch: 4 [30976/60000 (51.63%)]	Batch Loss: 0.179		Batch Accuracy: 94.53%
# Train Epoch: 4 [31104/60000 (51.84%)]	Batch Loss: 0.243		Batch Accuracy: 92.19%
# Train Epoch: 4 [31232/60000 (52.05%)]	Batch Loss: 0.154		Batch Accuracy: 96.09%
# Train Epoch: 4 [31360/60000 (52.27%)]	Batch Loss: 0.089		Batch Accuracy: 99.22%
# Train Epoch: 4 [31488/60000 (52.48%)]	Batch Loss: 0.290		Batch Accuracy: 93.75%
# Train Epoch: 4 [31616/60000 (52.69%)]	Batch Loss: 0.414		Batch Accuracy: 89.84%
# Train Epoch: 4 [31744/60000 (52.91%)]	Batch Loss: 0.300		Batch Accuracy: 91.41%
# Train Epoch: 4 [31872/60000 (53.12%)]	Batch Loss: 0.423		Batch Accuracy: 88.28%
# Train Epoch: 4 [32000/60000 (53.33%)]	Batch Loss: 0.387		Batch Accuracy: 89.84%
# Train Epoch: 4 [32128/60000 (53.55%)]	Batch Loss: 0.325		Batch Accuracy: 88.28%
# Train Epoch: 4 [32256/60000 (53.76%)]	Batch Loss: 0.214		Batch Accuracy: 93.75%
# Train Epoch: 4 [32384/60000 (53.97%)]	Batch Loss: 0.243		Batch Accuracy: 92.97%
# Train Epoch: 4 [32512/60000 (54.19%)]	Batch Loss: 0.348		Batch Accuracy: 90.62%
# Train Epoch: 4 [32640/60000 (54.40%)]	Batch Loss: 0.348		Batch Accuracy: 90.62%
# Train Epoch: 4 [32768/60000 (54.61%)]	Batch Loss: 0.367		Batch Accuracy: 86.72%
# Train Epoch: 4 [32896/60000 (54.83%)]	Batch Loss: 0.360		Batch Accuracy: 89.84%
# Train Epoch: 4 [33024/60000 (55.04%)]	Batch Loss: 0.290		Batch Accuracy: 89.84%
# Train Epoch: 4 [33152/60000 (55.25%)]	Batch Loss: 0.261		Batch Accuracy: 91.41%
# Train Epoch: 4 [33280/60000 (55.47%)]	Batch Loss: 0.309		Batch Accuracy: 90.62%
# Train Epoch: 4 [33408/60000 (55.68%)]	Batch Loss: 0.328		Batch Accuracy: 89.84%
# Train Epoch: 4 [33536/60000 (55.89%)]	Batch Loss: 0.194		Batch Accuracy: 95.31%
# Train Epoch: 4 [33664/60000 (56.11%)]	Batch Loss: 0.244		Batch Accuracy: 91.41%
# Train Epoch: 4 [33792/60000 (56.32%)]	Batch Loss: 0.161		Batch Accuracy: 97.66%
# Train Epoch: 4 [33920/60000 (56.53%)]	Batch Loss: 0.321		Batch Accuracy: 90.62%
# Train Epoch: 4 [34048/60000 (56.75%)]	Batch Loss: 0.274		Batch Accuracy: 90.62%
# Train Epoch: 4 [34176/60000 (56.96%)]	Batch Loss: 0.262		Batch Accuracy: 92.19%
# Train Epoch: 4 [34304/60000 (57.17%)]	Batch Loss: 0.247		Batch Accuracy: 92.19%
# Train Epoch: 4 [34432/60000 (57.39%)]	Batch Loss: 0.297		Batch Accuracy: 91.41%
# Train Epoch: 4 [34560/60000 (57.60%)]	Batch Loss: 0.293		Batch Accuracy: 92.97%
# Train Epoch: 4 [34688/60000 (57.81%)]	Batch Loss: 0.350		Batch Accuracy: 89.84%
# Train Epoch: 4 [34816/60000 (58.03%)]	Batch Loss: 0.412		Batch Accuracy: 85.16%
# Train Epoch: 4 [34944/60000 (58.24%)]	Batch Loss: 0.265		Batch Accuracy: 90.62%
# Train Epoch: 4 [35072/60000 (58.45%)]	Batch Loss: 0.214		Batch Accuracy: 93.75%
# Train Epoch: 4 [35200/60000 (58.67%)]	Batch Loss: 0.244		Batch Accuracy: 91.41%
# Train Epoch: 4 [35328/60000 (58.88%)]	Batch Loss: 0.261		Batch Accuracy: 89.06%
# Train Epoch: 4 [35456/60000 (59.09%)]	Batch Loss: 0.221		Batch Accuracy: 94.53%
# Train Epoch: 4 [35584/60000 (59.31%)]	Batch Loss: 0.302		Batch Accuracy: 91.41%
# Train Epoch: 4 [35712/60000 (59.52%)]	Batch Loss: 0.175		Batch Accuracy: 96.09%
# Train Epoch: 4 [35840/60000 (59.73%)]	Batch Loss: 0.289		Batch Accuracy: 91.41%
# Train Epoch: 4 [35968/60000 (59.95%)]	Batch Loss: 0.295		Batch Accuracy: 90.62%
# Train Epoch: 4 [36096/60000 (60.16%)]	Batch Loss: 0.361		Batch Accuracy: 88.28%
# Train Epoch: 4 [36224/60000 (60.37%)]	Batch Loss: 0.161		Batch Accuracy: 95.31%
# Train Epoch: 4 [36352/60000 (60.59%)]	Batch Loss: 0.293		Batch Accuracy: 89.06%
# Train Epoch: 4 [36480/60000 (60.80%)]	Batch Loss: 0.182		Batch Accuracy: 94.53%
# Train Epoch: 4 [36608/60000 (61.01%)]	Batch Loss: 0.355		Batch Accuracy: 89.84%
# Train Epoch: 4 [36736/60000 (61.23%)]	Batch Loss: 0.272		Batch Accuracy: 92.97%
# Train Epoch: 4 [36864/60000 (61.44%)]	Batch Loss: 0.216		Batch Accuracy: 91.41%
# Train Epoch: 4 [36992/60000 (61.65%)]	Batch Loss: 0.231		Batch Accuracy: 93.75%
# Train Epoch: 4 [37120/60000 (61.87%)]	Batch Loss: 0.266		Batch Accuracy: 91.41%
# Train Epoch: 4 [37248/60000 (62.08%)]	Batch Loss: 0.163		Batch Accuracy: 95.31%
# Train Epoch: 4 [37376/60000 (62.29%)]	Batch Loss: 0.310		Batch Accuracy: 89.84%
# Train Epoch: 4 [37504/60000 (62.51%)]	Batch Loss: 0.332		Batch Accuracy: 91.41%
# Train Epoch: 4 [37632/60000 (62.72%)]	Batch Loss: 0.303		Batch Accuracy: 89.06%
# Train Epoch: 4 [37760/60000 (62.93%)]	Batch Loss: 0.322		Batch Accuracy: 92.97%
# Train Epoch: 4 [37888/60000 (63.15%)]	Batch Loss: 0.238		Batch Accuracy: 91.41%
# Train Epoch: 4 [38016/60000 (63.36%)]	Batch Loss: 0.328		Batch Accuracy: 89.84%
# Train Epoch: 4 [38144/60000 (63.57%)]	Batch Loss: 0.358		Batch Accuracy: 89.06%
# Train Epoch: 4 [38272/60000 (63.79%)]	Batch Loss: 0.404		Batch Accuracy: 89.84%
# Train Epoch: 4 [38400/60000 (64.00%)]	Batch Loss: 0.267		Batch Accuracy: 92.19%
# Train Epoch: 4 [38528/60000 (64.21%)]	Batch Loss: 0.283		Batch Accuracy: 93.75%
# Train Epoch: 4 [38656/60000 (64.43%)]	Batch Loss: 0.235		Batch Accuracy: 92.19%
# Train Epoch: 4 [38784/60000 (64.64%)]	Batch Loss: 0.332		Batch Accuracy: 92.19%
# Train Epoch: 4 [38912/60000 (64.85%)]	Batch Loss: 0.414		Batch Accuracy: 86.72%
# Train Epoch: 4 [39040/60000 (65.07%)]	Batch Loss: 0.250		Batch Accuracy: 92.97%
# Train Epoch: 4 [39168/60000 (65.28%)]	Batch Loss: 0.234		Batch Accuracy: 91.41%
# Train Epoch: 4 [39296/60000 (65.49%)]	Batch Loss: 0.289		Batch Accuracy: 92.19%
# Train Epoch: 4 [39424/60000 (65.71%)]	Batch Loss: 0.315		Batch Accuracy: 90.62%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d752b6eed090> in <module>()
#       3 model.train()
#       4 for epoch in range(model.step+1, epochs):
# ----> 5   train_loss, train_acc = pred(model, datamodule, training = True)
#       6   print('Train Epoch {}| Loss: {:.3f}\tAccuracy: {:.2f}%'.format(epoch, train_loss, train_acc))
#       7
#
# <ipython-input-8-298e8c76fc50> in pred(model, datamodule, training)
#      20       loss = model.loss(logits, batch_y)
#      21       if training:
# ---> 22         model.gradient_descent(loss)
#      23       total_loss += loss.item() * batch_x.size(0)
#      24       batch_correct = model.correct(logits, batch_y).item()
#
# /content/drive/My Drive/Colab Notebooks/Paper/EXP/sources/model_loader.py in gradient_descent(self, loss)
#     110                 optim.zero_grad()
#     111
# --> 112         loss.backward()
#     113         #self.print_before_update()
#     114         if self.args.clip_norm > 0:
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %%
model.train_plot(train_log, 'Training Loss', 'Test Loss')

# %%
model.train_plot(train_log, 'Training Accuracy', 'Test Accuracy')
