# %%
root_path = '/content/drive/My Drive/Colab Notebooks/Paper/EXP/'
expr_path = root_path + 'Benchmark/MNIST/sMNIST/expRNN'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import_path = [root_path + subpath for subpath in ['sources/', 'sources/expRNN/']]
for path in import_path:
  sys.path.append(path)

# %%
import sys
import argparse
sys.argv = ['']
parser = argparse.ArgumentParser(description='expRNN MNIST Task')
parser.add_argument('--batch_size', type=int, default=128)
parser.add_argument('--hidden_size', type=int, default=170)
parser.add_argument('--epochs', type=int, default=70)
parser.add_argument('--use_adam', type=bool, default=False)
parser.add_argument('--adam_lr', type=float, default=1e-3)
parser.add_argument('--rmsprop_lr', type=float, default=7e-4)
parser.add_argument('--rmsprop_constr_lr', type=float, default=7e-5)
parser.add_argument('--alpha', type=float, default=0.99)
parser.add_argument('--clip_norm', type=float, default=-1)
parser.add_argument("--permute", action="store_true", default = False)
parser.add_argument("-m", "--mode",
                    choices=["exprnn", "dtriv", "cayley", "lstm", "rnn"],
                    default="exprnn",
                    type=str)
parser.add_argument('--K', type=str, default="100", help='The K parameter in the dtriv algorithm. It should be a positive integer or "infty".')
parser.add_argument("--init",
                    choices=["cayley", "henaff"],
                    default="cayley",
                    type=str)
parser.add_argument('--random-seed', type=int, default=5544,
                    help='random seed')
parser.add_argument('--rho_rat_den', type=int, default=10)
parser.add_argument('--forget_bias', type=int, default=1)
parser.add_argument('--emsize', type=int, default=0,
                    help='size of word embeddings')
#Setting
#https://arxiv.org/pdf/1901.08428.pdf
#https://arxiv.org/abs/1905.12080
args = parser.parse_args(['--hidden_size', '170', '--epochs', '70', '--rmsprop_lr', '7e-4', '--rmsprop_constr_lr', '7e-5', '-mexprnn'])
print(args)
# Out:
# Namespace(K='100', adam_lr=0.001, alpha=0.99, batch_size=128, clip_norm=-1, clip_val=-1, emsize=0, epochs=70, forget_bias=1, hidden_size=170, init='cayley', mode='exprnn', permute=False, random_seed=5544, rho_rat_den=10, rmsprop_constr_lr=7e-05, rmsprop_lr=0.0007, use_adam=False)

# %%
import torch
import numpy as np
import random
import os
# Fix seed across experiments
# Same seed as that used in "Orthogonal Recurrent Neural Networks with Scaled Cayley Transform"
# https://github.com/SpartinStuff/scoRNN/blob/master/scoRNN_copying.py#L79
torch.use_deterministic_algorithms(True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(args.random_seed)
np.random.seed(args.random_seed)
random.seed(args.random_seed)

#Deterministic training
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ":4096:8" #increase library footprint in GPU memory by approximately 24MiB
#os.environ['CUBLAS_WORKSPACE_CONFIG'] = ":16:8" #(may limit overall performance)"

# %%
from trivializations import cayley_map, expm
from initialization import henaff_init_, cayley_init_
from data_module import MNISTDataModule
from torch.nn import Embedding

sequence_length = 784
hidden_size = args.hidden_size
batch_size  = args.batch_size
epochs      = args.epochs
device      = device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_first = True
many_to_many = False
epochs_to_save = 1

if args.init == "cayley":
    init =  cayley_init_
elif args.init == "henaff":
    init = henaff_init_

if args.K != "infty":
    args.K = int(args.K)
if args.mode == "exprnn":
    mode = "static"
    param = expm
elif args.mode == "dtriv":
    # We use 100 as the default to project back to the manifold.
    # This parameter does not really affect the convergence of the algorithms, even for K=1
    mode = ("dynamic", args.K, 100)
    param = expm
elif args.mode == "cayley":
    mode = "static"
    param = cayley_map

#Setting up data module
# Load data   
dataset_path = root_path + 'Dataset/MNIST/'
if args.permute:
  datamodule = MNISTDataModule(sequence_length, 784 // sequence_length, batch_size, dataset_path, permute_seed = 92916)
else:
  datamodule = MNISTDataModule(sequence_length, 784 // sequence_length, batch_size, dataset_path, permute_seed = None)

if args.emsize > 0:
  embed_layer = Embedding(datamodule.input_size, args.emsize) # Token2Embeddings
  input_size = args.emsize
else:
  embed_layer = None
  input_size = datamodule.input_size

# %%
from model_loader import Model
from custom_modules import AMSAF_SVD
from orthogonal import modrelu

#Initialize Model
nonlinearity = modrelu(hidden_size)
model = Model(input_size, hidden_size, datamodule.output_size, nonlinearity, initializer_skew = init,
              mode = mode, param = param, args=args, embed_layer=embed_layer, batch_first=batch_first, many_to_many = many_to_many).to(device)
#Initialize Optimizers
unconstrained_parameters = []
constrained_parameters = []

for name, p in model.named_parameters():
    if any(map(name.__contains__, ['recurrent_kernel'])):
        constrained_parameters.append(p)
    else:
        unconstrained_parameters.append(p)
if args.use_adam:
  adam_optim = torch.optim.Adam(unconstrained_parameters, lr=args.adam_lr)
  rmsprop_optim = torch.optim.RMSprop(constrained_parameters, lr=args.rmsprop_constr_lr)
else:
  rmsprop_optim = torch.optim.RMSprop([
                  {'params': unconstrained_parameters},
                  {'params': constrained_parameters, 'lr': args.rmsprop_constr_lr}
              ], lr=args.rmsprop_lr, alpha = args.alpha)
  adam_optim = None

optim_list = [optim for optim in [rmsprop_optim, adam_optim] if optim]
model.setup_optimizer_list(optim_list)

column_names = ['Epoch', 'Training Loss', 'Training Accuracy', 'Test Loss', 'Test Accuracy']
train_log = model.load_log_df(epochs_to_save, expr_path, column_names)

# %%
def pred(model, datamodule, training = True):
  global device
  total_loss = 0.0
  total_acc = 0.0
  sample_num = 0

  if training:
    data_enum = datamodule.train_enum()
    data_len = datamodule.train_len
  else:
    data_enum = datamodule.test_enum()
    data_len = datamodule.test_len

  for batch_x, batch_y in data_enum:
      batch_x, batch_y = batch_x.to(device).view(-1, datamodule.sequence_length, datamodule.input_size), batch_y.to(device)
      state = None
      state = model.state_reprocess(batch_x, state)

      logits = model.compute_logits(batch_x, state)
      loss = model.loss(logits, batch_y)
      if training:
        model.gradient_descent(loss)
      total_loss += loss.item() * batch_x.size(0)
      batch_correct = model.correct(logits, batch_y).item()
      total_acc += batch_correct
      sample_num += batch_x.size(0)
      
      if training: #For tracking training progress
        print('Train Epoch: {} [{}/{} ({:.2f}%)]\tBatch Loss: {:.3f}\t\tBatch Accuracy: {:.2f}%'.format(model.step+1, sample_num, datamodule.train_len,
                    model.average_value(100. * sample_num, datamodule.train_len, 2), loss.item(), model.average_value(100 * batch_correct, len(batch_x), 2)))
        
  total_loss = model.average_value(total_loss, data_len, 3)
  total_acc = model.average_value(100 * total_acc, data_len, 2)
  return total_loss, total_acc

# %%
def save_model(epochs_to_save, experiment_path):
  if (model.step % epochs_to_save == 0):
    if ((model.step // epochs_to_save) % 2) == 1:
      model.save_state(experiment_path+'/last_odd.ckpt')
    else:
      model.save_state(experiment_path+'/last_even.ckpt')

# %%
import pandas as pd
#Training
model.train()
for epoch in range(model.step+1, epochs):
  train_loss, train_acc = pred(model, datamodule, training = True)
  print('Train Epoch {}| Loss: {:.3f}\tAccuracy: {:.2f}%'.format(epoch, train_loss, train_acc))

  model.eval()
  with torch.no_grad():
      test_loss, test_acc = pred(model, datamodule, training = False)
  if len(train_log) == 0:
    best_test_acc = test_acc
  else:
    best_test_acc = max(train_log["Test Accuracy"].max(), test_acc)
  print('Test Epoch {}| Loss: {:.3f}\tAccuracy: {:.2f}%\tBest Accuracy: {:.2f}'.format(epoch, test_loss, test_acc, best_test_acc))       

  model.step = epoch #update_log_df and save_model requires this command
  new_row = pd.Series({"Epoch": epoch, "Training Loss": train_loss, "Training Accuracy": train_acc,
                        "Test Loss": test_loss, 'Test Accuracy': test_acc})
  train_log = model.update_log_df(new_row, train_log, expr_path+'/train_log.pkl')
  save_model(epochs_to_save, expr_path)
  model.train()
# Out:
# Train Epoch: 69 [128/60000 (0.21%)]	Batch Loss: 0.061		Batch Accuracy: 97.66%
# Train Epoch: 69 [256/60000 (0.43%)]	Batch Loss: 0.028		Batch Accuracy: 99.22%
# Train Epoch: 69 [384/60000 (0.64%)]	Batch Loss: 0.031		Batch Accuracy: 97.66%
# Train Epoch: 69 [512/60000 (0.85%)]	Batch Loss: 0.048		Batch Accuracy: 97.66%
# Train Epoch: 69 [640/60000 (1.07%)]	Batch Loss: 0.024		Batch Accuracy: 100.00%
# Train Epoch: 69 [768/60000 (1.28%)]	Batch Loss: 0.017		Batch Accuracy: 99.22%
# Train Epoch: 69 [896/60000 (1.49%)]	Batch Loss: 0.043		Batch Accuracy: 97.66%
# Train Epoch: 69 [1024/60000 (1.71%)]	Batch Loss: 0.053		Batch Accuracy: 97.66%
# Train Epoch: 69 [1152/60000 (1.92%)]	Batch Loss: 0.020		Batch Accuracy: 100.00%
# Train Epoch: 69 [1280/60000 (2.13%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [1408/60000 (2.35%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [1536/60000 (2.56%)]	Batch Loss: 0.050		Batch Accuracy: 99.22%
# Train Epoch: 69 [1664/60000 (2.77%)]	Batch Loss: 0.015		Batch Accuracy: 100.00%
# Train Epoch: 69 [1792/60000 (2.99%)]	Batch Loss: 0.023		Batch Accuracy: 99.22%
# Train Epoch: 69 [1920/60000 (3.20%)]	Batch Loss: 0.017		Batch Accuracy: 100.00%
# Train Epoch: 69 [2048/60000 (3.41%)]	Batch Loss: 0.048		Batch Accuracy: 97.66%
# Train Epoch: 69 [2176/60000 (3.63%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [2304/60000 (3.84%)]	Batch Loss: 0.015		Batch Accuracy: 100.00%
# Train Epoch: 69 [2432/60000 (4.05%)]	Batch Loss: 0.023		Batch Accuracy: 99.22%
# Train Epoch: 69 [2560/60000 (4.27%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [2688/60000 (4.48%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [2816/60000 (4.69%)]	Batch Loss: 0.016		Batch Accuracy: 100.00%
# Train Epoch: 69 [2944/60000 (4.91%)]	Batch Loss: 0.037		Batch Accuracy: 98.44%
# Train Epoch: 69 [3072/60000 (5.12%)]	Batch Loss: 0.052		Batch Accuracy: 98.44%
# Train Epoch: 69 [3200/60000 (5.33%)]	Batch Loss: 0.068		Batch Accuracy: 96.88%
# Train Epoch: 69 [3328/60000 (5.55%)]	Batch Loss: 0.049		Batch Accuracy: 97.66%
# Train Epoch: 69 [3456/60000 (5.76%)]	Batch Loss: 0.101		Batch Accuracy: 96.09%
# Train Epoch: 69 [3584/60000 (5.97%)]	Batch Loss: 0.071		Batch Accuracy: 97.66%
# Train Epoch: 69 [3712/60000 (6.19%)]	Batch Loss: 0.030		Batch Accuracy: 98.44%
# Train Epoch: 69 [3840/60000 (6.40%)]	Batch Loss: 0.042		Batch Accuracy: 99.22%
# Train Epoch: 69 [3968/60000 (6.61%)]	Batch Loss: 0.046		Batch Accuracy: 98.44%
# Train Epoch: 69 [4096/60000 (6.83%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [4224/60000 (7.04%)]	Batch Loss: 0.101		Batch Accuracy: 97.66%
# Train Epoch: 69 [4352/60000 (7.25%)]	Batch Loss: 0.123		Batch Accuracy: 96.09%
# Train Epoch: 69 [4480/60000 (7.47%)]	Batch Loss: 0.049		Batch Accuracy: 97.66%
# Train Epoch: 69 [4608/60000 (7.68%)]	Batch Loss: 0.053		Batch Accuracy: 98.44%
# Train Epoch: 69 [4736/60000 (7.89%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [4864/60000 (8.11%)]	Batch Loss: 0.047		Batch Accuracy: 97.66%
# Train Epoch: 69 [4992/60000 (8.32%)]	Batch Loss: 0.030		Batch Accuracy: 99.22%
# Train Epoch: 69 [5120/60000 (8.53%)]	Batch Loss: 0.046		Batch Accuracy: 97.66%
# Train Epoch: 69 [5248/60000 (8.75%)]	Batch Loss: 0.008		Batch Accuracy: 100.00%
# Train Epoch: 69 [5376/60000 (8.96%)]	Batch Loss: 0.041		Batch Accuracy: 97.66%
# Train Epoch: 69 [5504/60000 (9.17%)]	Batch Loss: 0.022		Batch Accuracy: 99.22%
# Train Epoch: 69 [5632/60000 (9.39%)]	Batch Loss: 0.068		Batch Accuracy: 96.88%
# Train Epoch: 69 [5760/60000 (9.60%)]	Batch Loss: 0.015		Batch Accuracy: 99.22%
# Train Epoch: 69 [5888/60000 (9.81%)]	Batch Loss: 0.075		Batch Accuracy: 97.66%
# Train Epoch: 69 [6016/60000 (10.03%)]	Batch Loss: 0.016		Batch Accuracy: 99.22%
# Train Epoch: 69 [6144/60000 (10.24%)]	Batch Loss: 0.051		Batch Accuracy: 98.44%
# Train Epoch: 69 [6272/60000 (10.45%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [6400/60000 (10.67%)]	Batch Loss: 0.045		Batch Accuracy: 99.22%
# Train Epoch: 69 [6528/60000 (10.88%)]	Batch Loss: 0.019		Batch Accuracy: 99.22%
# Train Epoch: 69 [6656/60000 (11.09%)]	Batch Loss: 0.052		Batch Accuracy: 98.44%
# Train Epoch: 69 [6784/60000 (11.31%)]	Batch Loss: 0.023		Batch Accuracy: 99.22%
# Train Epoch: 69 [6912/60000 (11.52%)]	Batch Loss: 0.035		Batch Accuracy: 97.66%
# Train Epoch: 69 [7040/60000 (11.73%)]	Batch Loss: 0.048		Batch Accuracy: 97.66%
# Train Epoch: 69 [7168/60000 (11.95%)]	Batch Loss: 0.060		Batch Accuracy: 97.66%
# Train Epoch: 69 [7296/60000 (12.16%)]	Batch Loss: 0.042		Batch Accuracy: 99.22%
# Train Epoch: 69 [7424/60000 (12.37%)]	Batch Loss: 0.038		Batch Accuracy: 99.22%
# Train Epoch: 69 [7552/60000 (12.59%)]	Batch Loss: 0.075		Batch Accuracy: 98.44%
# Train Epoch: 69 [7680/60000 (12.80%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [7808/60000 (13.01%)]	Batch Loss: 0.015		Batch Accuracy: 99.22%
# Train Epoch: 69 [7936/60000 (13.23%)]	Batch Loss: 0.024		Batch Accuracy: 99.22%
# Train Epoch: 69 [8064/60000 (13.44%)]	Batch Loss: 0.048		Batch Accuracy: 97.66%
# Train Epoch: 69 [8192/60000 (13.65%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [8320/60000 (13.87%)]	Batch Loss: 0.086		Batch Accuracy: 96.88%
# Train Epoch: 69 [8448/60000 (14.08%)]	Batch Loss: 0.031		Batch Accuracy: 99.22%
# Train Epoch: 69 [8576/60000 (14.29%)]	Batch Loss: 0.023		Batch Accuracy: 99.22%
# Train Epoch: 69 [8704/60000 (14.51%)]	Batch Loss: 0.015		Batch Accuracy: 100.00%
# Train Epoch: 69 [8832/60000 (14.72%)]	Batch Loss: 0.036		Batch Accuracy: 99.22%
# Train Epoch: 69 [8960/60000 (14.93%)]	Batch Loss: 0.020		Batch Accuracy: 100.00%
# Train Epoch: 69 [9088/60000 (15.15%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [9216/60000 (15.36%)]	Batch Loss: 0.082		Batch Accuracy: 97.66%
# Train Epoch: 69 [9344/60000 (15.57%)]	Batch Loss: 0.021		Batch Accuracy: 99.22%
# Train Epoch: 69 [9472/60000 (15.79%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [9600/60000 (16.00%)]	Batch Loss: 0.047		Batch Accuracy: 97.66%
# Train Epoch: 69 [9728/60000 (16.21%)]	Batch Loss: 0.049		Batch Accuracy: 98.44%
# Train Epoch: 69 [9856/60000 (16.43%)]	Batch Loss: 0.059		Batch Accuracy: 96.88%
# Train Epoch: 69 [9984/60000 (16.64%)]	Batch Loss: 0.027		Batch Accuracy: 98.44%
# Train Epoch: 69 [10112/60000 (16.85%)]	Batch Loss: 0.076		Batch Accuracy: 97.66%
# Train Epoch: 69 [10240/60000 (17.07%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [10368/60000 (17.28%)]	Batch Loss: 0.032		Batch Accuracy: 99.22%
# Train Epoch: 69 [10496/60000 (17.49%)]	Batch Loss: 0.015		Batch Accuracy: 100.00%
# Train Epoch: 69 [10624/60000 (17.71%)]	Batch Loss: 0.037		Batch Accuracy: 97.66%
# Train Epoch: 69 [10752/60000 (17.92%)]	Batch Loss: 0.019		Batch Accuracy: 99.22%
# Train Epoch: 69 [10880/60000 (18.13%)]	Batch Loss: 0.028		Batch Accuracy: 99.22%
# Train Epoch: 69 [11008/60000 (18.35%)]	Batch Loss: 0.029		Batch Accuracy: 99.22%
# Train Epoch: 69 [11136/60000 (18.56%)]	Batch Loss: 0.044		Batch Accuracy: 98.44%
# Train Epoch: 69 [11264/60000 (18.77%)]	Batch Loss: 0.041		Batch Accuracy: 97.66%
# Train Epoch: 69 [11392/60000 (18.99%)]	Batch Loss: 0.017		Batch Accuracy: 100.00%
# Train Epoch: 69 [11520/60000 (19.20%)]	Batch Loss: 0.010		Batch Accuracy: 100.00%
# Train Epoch: 69 [11648/60000 (19.41%)]	Batch Loss: 0.018		Batch Accuracy: 100.00%
# Train Epoch: 69 [11776/60000 (19.63%)]	Batch Loss: 0.047		Batch Accuracy: 98.44%
# Train Epoch: 69 [11904/60000 (19.84%)]	Batch Loss: 0.060		Batch Accuracy: 98.44%
# Train Epoch: 69 [12032/60000 (20.05%)]	Batch Loss: 0.102		Batch Accuracy: 96.88%
# Train Epoch: 69 [12160/60000 (20.27%)]	Batch Loss: 0.121		Batch Accuracy: 98.44%
# Train Epoch: 69 [12288/60000 (20.48%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [12416/60000 (20.69%)]	Batch Loss: 0.051		Batch Accuracy: 97.66%
# Train Epoch: 69 [12544/60000 (20.91%)]	Batch Loss: 0.046		Batch Accuracy: 97.66%
# Train Epoch: 69 [12672/60000 (21.12%)]	Batch Loss: 0.132		Batch Accuracy: 95.31%
# Train Epoch: 69 [12800/60000 (21.33%)]	Batch Loss: 0.025		Batch Accuracy: 100.00%
# Train Epoch: 69 [12928/60000 (21.55%)]	Batch Loss: 0.047		Batch Accuracy: 98.44%
# Train Epoch: 69 [13056/60000 (21.76%)]	Batch Loss: 0.037		Batch Accuracy: 98.44%
# Train Epoch: 69 [13184/60000 (21.97%)]	Batch Loss: 0.023		Batch Accuracy: 99.22%
# Train Epoch: 69 [13312/60000 (22.19%)]	Batch Loss: 0.085		Batch Accuracy: 97.66%
# Train Epoch: 69 [13440/60000 (22.40%)]	Batch Loss: 0.038		Batch Accuracy: 99.22%
# Train Epoch: 69 [13568/60000 (22.61%)]	Batch Loss: 0.019		Batch Accuracy: 99.22%
# Train Epoch: 69 [13696/60000 (22.83%)]	Batch Loss: 0.075		Batch Accuracy: 97.66%
# Train Epoch: 69 [13824/60000 (23.04%)]	Batch Loss: 0.048		Batch Accuracy: 99.22%
# Train Epoch: 69 [13952/60000 (23.25%)]	Batch Loss: 0.060		Batch Accuracy: 98.44%
# Train Epoch: 69 [14080/60000 (23.47%)]	Batch Loss: 0.054		Batch Accuracy: 98.44%
# Train Epoch: 69 [14208/60000 (23.68%)]	Batch Loss: 0.087		Batch Accuracy: 98.44%
# Train Epoch: 69 [14336/60000 (23.89%)]	Batch Loss: 0.088		Batch Accuracy: 96.09%
# Train Epoch: 69 [14464/60000 (24.11%)]	Batch Loss: 0.072		Batch Accuracy: 96.09%
# Train Epoch: 69 [14592/60000 (24.32%)]	Batch Loss: 0.062		Batch Accuracy: 98.44%
# Train Epoch: 69 [14720/60000 (24.53%)]	Batch Loss: 0.056		Batch Accuracy: 97.66%
# Train Epoch: 69 [14848/60000 (24.75%)]	Batch Loss: 0.107		Batch Accuracy: 95.31%
# Train Epoch: 69 [14976/60000 (24.96%)]	Batch Loss: 0.064		Batch Accuracy: 97.66%
# Train Epoch: 69 [15104/60000 (25.17%)]	Batch Loss: 0.048		Batch Accuracy: 98.44%
# Train Epoch: 69 [15232/60000 (25.39%)]	Batch Loss: 0.076		Batch Accuracy: 97.66%
# Train Epoch: 69 [15360/60000 (25.60%)]	Batch Loss: 0.013		Batch Accuracy: 100.00%
# Train Epoch: 69 [15488/60000 (25.81%)]	Batch Loss: 0.061		Batch Accuracy: 97.66%
# Train Epoch: 69 [15616/60000 (26.03%)]	Batch Loss: 0.047		Batch Accuracy: 98.44%
# Train Epoch: 69 [15744/60000 (26.24%)]	Batch Loss: 0.013		Batch Accuracy: 100.00%
# Train Epoch: 69 [15872/60000 (26.45%)]	Batch Loss: 0.063		Batch Accuracy: 97.66%
# Train Epoch: 69 [16000/60000 (26.67%)]	Batch Loss: 0.082		Batch Accuracy: 95.31%
# Train Epoch: 69 [16128/60000 (26.88%)]	Batch Loss: 0.059		Batch Accuracy: 98.44%
# Train Epoch: 69 [16256/60000 (27.09%)]	Batch Loss: 0.049		Batch Accuracy: 98.44%
# Train Epoch: 69 [16384/60000 (27.31%)]	Batch Loss: 0.066		Batch Accuracy: 97.66%
# Train Epoch: 69 [16512/60000 (27.52%)]	Batch Loss: 0.089		Batch Accuracy: 97.66%
# Train Epoch: 69 [16640/60000 (27.73%)]	Batch Loss: 0.025		Batch Accuracy: 99.22%
# Train Epoch: 69 [16768/60000 (27.95%)]	Batch Loss: 0.108		Batch Accuracy: 97.66%
# Train Epoch: 69 [16896/60000 (28.16%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [17024/60000 (28.37%)]	Batch Loss: 0.032		Batch Accuracy: 99.22%
# Train Epoch: 69 [17152/60000 (28.59%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [17280/60000 (28.80%)]	Batch Loss: 0.008		Batch Accuracy: 100.00%
# Train Epoch: 69 [17408/60000 (29.01%)]	Batch Loss: 0.033		Batch Accuracy: 98.44%
# Train Epoch: 69 [17536/60000 (29.23%)]	Batch Loss: 0.047		Batch Accuracy: 97.66%
# Train Epoch: 69 [17664/60000 (29.44%)]	Batch Loss: 0.044		Batch Accuracy: 99.22%
# Train Epoch: 69 [17792/60000 (29.65%)]	Batch Loss: 0.034		Batch Accuracy: 98.44%
# Train Epoch: 69 [17920/60000 (29.87%)]	Batch Loss: 0.041		Batch Accuracy: 98.44%
# Train Epoch: 69 [18048/60000 (30.08%)]	Batch Loss: 0.033		Batch Accuracy: 99.22%
# Train Epoch: 69 [18176/60000 (30.29%)]	Batch Loss: 0.067		Batch Accuracy: 98.44%
# Train Epoch: 69 [18304/60000 (30.51%)]	Batch Loss: 0.047		Batch Accuracy: 97.66%
# Train Epoch: 69 [18432/60000 (30.72%)]	Batch Loss: 0.035		Batch Accuracy: 99.22%
# Train Epoch: 69 [18560/60000 (30.93%)]	Batch Loss: 0.032		Batch Accuracy: 98.44%
# Train Epoch: 69 [18688/60000 (31.15%)]	Batch Loss: 0.033		Batch Accuracy: 98.44%
# Train Epoch: 69 [18816/60000 (31.36%)]	Batch Loss: 0.059		Batch Accuracy: 96.88%
# Train Epoch: 69 [18944/60000 (31.57%)]	Batch Loss: 0.033		Batch Accuracy: 98.44%
# Train Epoch: 69 [19072/60000 (31.79%)]	Batch Loss: 0.036		Batch Accuracy: 98.44%
# Train Epoch: 69 [19200/60000 (32.00%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [19328/60000 (32.21%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [19456/60000 (32.43%)]	Batch Loss: 0.044		Batch Accuracy: 98.44%
# Train Epoch: 69 [19584/60000 (32.64%)]	Batch Loss: 0.031		Batch Accuracy: 99.22%
# Train Epoch: 69 [19712/60000 (32.85%)]	Batch Loss: 0.032		Batch Accuracy: 98.44%
# Train Epoch: 69 [19840/60000 (33.07%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [19968/60000 (33.28%)]	Batch Loss: 0.031		Batch Accuracy: 98.44%
# Train Epoch: 69 [20096/60000 (33.49%)]	Batch Loss: 0.024		Batch Accuracy: 99.22%
# Train Epoch: 69 [20224/60000 (33.71%)]	Batch Loss: 0.013		Batch Accuracy: 100.00%
# Train Epoch: 69 [20352/60000 (33.92%)]	Batch Loss: 0.037		Batch Accuracy: 99.22%
# Train Epoch: 69 [20480/60000 (34.13%)]	Batch Loss: 0.010		Batch Accuracy: 100.00%
# Train Epoch: 69 [20608/60000 (34.35%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [20736/60000 (34.56%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [20864/60000 (34.77%)]	Batch Loss: 0.068		Batch Accuracy: 99.22%
# Train Epoch: 69 [20992/60000 (34.99%)]	Batch Loss: 0.050		Batch Accuracy: 97.66%
# Train Epoch: 69 [21120/60000 (35.20%)]	Batch Loss: 0.047		Batch Accuracy: 98.44%
# Train Epoch: 69 [21248/60000 (35.41%)]	Batch Loss: 0.061		Batch Accuracy: 98.44%
# Train Epoch: 69 [21376/60000 (35.63%)]	Batch Loss: 0.042		Batch Accuracy: 98.44%
# Train Epoch: 69 [21504/60000 (35.84%)]	Batch Loss: 0.049		Batch Accuracy: 96.88%
# Train Epoch: 69 [21632/60000 (36.05%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [21760/60000 (36.27%)]	Batch Loss: 0.020		Batch Accuracy: 100.00%
# Train Epoch: 69 [21888/60000 (36.48%)]	Batch Loss: 0.038		Batch Accuracy: 99.22%
# Train Epoch: 69 [22016/60000 (36.69%)]	Batch Loss: 0.044		Batch Accuracy: 98.44%
# Train Epoch: 69 [22144/60000 (36.91%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [22272/60000 (37.12%)]	Batch Loss: 0.021		Batch Accuracy: 100.00%
# Train Epoch: 69 [22400/60000 (37.33%)]	Batch Loss: 0.043		Batch Accuracy: 99.22%
# Train Epoch: 69 [22528/60000 (37.55%)]	Batch Loss: 0.033		Batch Accuracy: 99.22%
# Train Epoch: 69 [22656/60000 (37.76%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [22784/60000 (37.97%)]	Batch Loss: 0.019		Batch Accuracy: 100.00%
# Train Epoch: 69 [22912/60000 (38.19%)]	Batch Loss: 0.056		Batch Accuracy: 97.66%
# Train Epoch: 69 [23040/60000 (38.40%)]	Batch Loss: 0.074		Batch Accuracy: 98.44%
# Train Epoch: 69 [23168/60000 (38.61%)]	Batch Loss: 0.042		Batch Accuracy: 99.22%
# Train Epoch: 69 [23296/60000 (38.83%)]	Batch Loss: 0.022		Batch Accuracy: 98.44%
# Train Epoch: 69 [23424/60000 (39.04%)]	Batch Loss: 0.061		Batch Accuracy: 96.88%
# Train Epoch: 69 [23552/60000 (39.25%)]	Batch Loss: 0.010		Batch Accuracy: 100.00%
# Train Epoch: 69 [23680/60000 (39.47%)]	Batch Loss: 0.026		Batch Accuracy: 99.22%
# Train Epoch: 69 [23808/60000 (39.68%)]	Batch Loss: 0.041		Batch Accuracy: 97.66%
# Train Epoch: 69 [23936/60000 (39.89%)]	Batch Loss: 0.056		Batch Accuracy: 97.66%
# Train Epoch: 69 [24064/60000 (40.11%)]	Batch Loss: 0.046		Batch Accuracy: 97.66%
# Train Epoch: 69 [24192/60000 (40.32%)]	Batch Loss: 0.040		Batch Accuracy: 99.22%
# Train Epoch: 69 [24320/60000 (40.53%)]	Batch Loss: 0.047		Batch Accuracy: 99.22%
# Train Epoch: 69 [24448/60000 (40.75%)]	Batch Loss: 0.057		Batch Accuracy: 98.44%
# Train Epoch: 69 [24576/60000 (40.96%)]	Batch Loss: 0.051		Batch Accuracy: 98.44%
# Train Epoch: 69 [24704/60000 (41.17%)]	Batch Loss: 0.037		Batch Accuracy: 97.66%
# Train Epoch: 69 [24832/60000 (41.39%)]	Batch Loss: 0.043		Batch Accuracy: 98.44%
# Train Epoch: 69 [24960/60000 (41.60%)]	Batch Loss: 0.062		Batch Accuracy: 97.66%
# Train Epoch: 69 [25088/60000 (41.81%)]	Batch Loss: 0.026		Batch Accuracy: 99.22%
# Train Epoch: 69 [25216/60000 (42.03%)]	Batch Loss: 0.048		Batch Accuracy: 99.22%
# Train Epoch: 69 [25344/60000 (42.24%)]	Batch Loss: 0.016		Batch Accuracy: 100.00%
# Train Epoch: 69 [25472/60000 (42.45%)]	Batch Loss: 0.051		Batch Accuracy: 97.66%
# Train Epoch: 69 [25600/60000 (42.67%)]	Batch Loss: 0.031		Batch Accuracy: 100.00%
# Train Epoch: 69 [25728/60000 (42.88%)]	Batch Loss: 0.024		Batch Accuracy: 98.44%
# Train Epoch: 69 [25856/60000 (43.09%)]	Batch Loss: 0.041		Batch Accuracy: 98.44%
# Train Epoch: 69 [25984/60000 (43.31%)]	Batch Loss: 0.014		Batch Accuracy: 100.00%
# Train Epoch: 69 [26112/60000 (43.52%)]	Batch Loss: 0.025		Batch Accuracy: 99.22%
# Train Epoch: 69 [26240/60000 (43.73%)]	Batch Loss: 0.051		Batch Accuracy: 98.44%
# Train Epoch: 69 [26368/60000 (43.95%)]	Batch Loss: 0.050		Batch Accuracy: 98.44%
# Train Epoch: 69 [26496/60000 (44.16%)]	Batch Loss: 0.061		Batch Accuracy: 97.66%
# Train Epoch: 69 [26624/60000 (44.37%)]	Batch Loss: 0.039		Batch Accuracy: 97.66%
# Train Epoch: 69 [26752/60000 (44.59%)]	Batch Loss: 0.045		Batch Accuracy: 98.44%
# Train Epoch: 69 [26880/60000 (44.80%)]	Batch Loss: 0.024		Batch Accuracy: 99.22%
# Train Epoch: 69 [27008/60000 (45.01%)]	Batch Loss: 0.071		Batch Accuracy: 98.44%
# Train Epoch: 69 [27136/60000 (45.23%)]	Batch Loss: 0.050		Batch Accuracy: 99.22%
# Train Epoch: 69 [27264/60000 (45.44%)]	Batch Loss: 0.070		Batch Accuracy: 96.88%
# Train Epoch: 69 [27392/60000 (45.65%)]	Batch Loss: 0.044		Batch Accuracy: 98.44%
# Train Epoch: 69 [27520/60000 (45.87%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [27648/60000 (46.08%)]	Batch Loss: 0.029		Batch Accuracy: 97.66%
# Train Epoch: 69 [27776/60000 (46.29%)]	Batch Loss: 0.072		Batch Accuracy: 96.88%
# Train Epoch: 69 [27904/60000 (46.51%)]	Batch Loss: 0.041		Batch Accuracy: 99.22%
# Train Epoch: 69 [28032/60000 (46.72%)]	Batch Loss: 0.055		Batch Accuracy: 98.44%
# Train Epoch: 69 [28160/60000 (46.93%)]	Batch Loss: 0.021		Batch Accuracy: 99.22%
# Train Epoch: 69 [28288/60000 (47.15%)]	Batch Loss: 0.036		Batch Accuracy: 99.22%
# Train Epoch: 69 [28416/60000 (47.36%)]	Batch Loss: 0.069		Batch Accuracy: 96.88%
# Train Epoch: 69 [28544/60000 (47.57%)]	Batch Loss: 0.029		Batch Accuracy: 99.22%
# Train Epoch: 69 [28672/60000 (47.79%)]	Batch Loss: 0.096		Batch Accuracy: 98.44%
# Train Epoch: 69 [28800/60000 (48.00%)]	Batch Loss: 0.019		Batch Accuracy: 99.22%
# Train Epoch: 69 [28928/60000 (48.21%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [29056/60000 (48.43%)]	Batch Loss: 0.087		Batch Accuracy: 97.66%
# Train Epoch: 69 [29184/60000 (48.64%)]	Batch Loss: 0.026		Batch Accuracy: 98.44%
# Train Epoch: 69 [29312/60000 (48.85%)]	Batch Loss: 0.026		Batch Accuracy: 99.22%
# Train Epoch: 69 [29440/60000 (49.07%)]	Batch Loss: 0.055		Batch Accuracy: 98.44%
# Train Epoch: 69 [29568/60000 (49.28%)]	Batch Loss: 0.089		Batch Accuracy: 97.66%
# Train Epoch: 69 [29696/60000 (49.49%)]	Batch Loss: 0.013		Batch Accuracy: 99.22%
# Train Epoch: 69 [29824/60000 (49.71%)]	Batch Loss: 0.085		Batch Accuracy: 97.66%
# Train Epoch: 69 [29952/60000 (49.92%)]	Batch Loss: 0.056		Batch Accuracy: 96.88%
# Train Epoch: 69 [30080/60000 (50.13%)]	Batch Loss: 0.112		Batch Accuracy: 97.66%
# Train Epoch: 69 [30208/60000 (50.35%)]	Batch Loss: 0.010		Batch Accuracy: 100.00%
# Train Epoch: 69 [30336/60000 (50.56%)]	Batch Loss: 0.066		Batch Accuracy: 97.66%
# Train Epoch: 69 [30464/60000 (50.77%)]	Batch Loss: 0.022		Batch Accuracy: 99.22%
# Train Epoch: 69 [30592/60000 (50.99%)]	Batch Loss: 0.080		Batch Accuracy: 96.88%
# Train Epoch: 69 [30720/60000 (51.20%)]	Batch Loss: 0.034		Batch Accuracy: 98.44%
# Train Epoch: 69 [30848/60000 (51.41%)]	Batch Loss: 0.054		Batch Accuracy: 97.66%
# Train Epoch: 69 [30976/60000 (51.63%)]	Batch Loss: 0.049		Batch Accuracy: 98.44%
# Train Epoch: 69 [31104/60000 (51.84%)]	Batch Loss: 0.110		Batch Accuracy: 96.09%
# Train Epoch: 69 [31232/60000 (52.05%)]	Batch Loss: 0.032		Batch Accuracy: 98.44%
# Train Epoch: 69 [31360/60000 (52.27%)]	Batch Loss: 0.037		Batch Accuracy: 99.22%
# Train Epoch: 69 [31488/60000 (52.48%)]	Batch Loss: 0.035		Batch Accuracy: 99.22%
# Train Epoch: 69 [31616/60000 (52.69%)]	Batch Loss: 0.026		Batch Accuracy: 99.22%
# Train Epoch: 69 [31744/60000 (52.91%)]	Batch Loss: 0.021		Batch Accuracy: 100.00%
# Train Epoch: 69 [31872/60000 (53.12%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [32000/60000 (53.33%)]	Batch Loss: 0.018		Batch Accuracy: 100.00%
# Train Epoch: 69 [32128/60000 (53.55%)]	Batch Loss: 0.015		Batch Accuracy: 99.22%
# Train Epoch: 69 [32256/60000 (53.76%)]	Batch Loss: 0.059		Batch Accuracy: 97.66%
# Train Epoch: 69 [32384/60000 (53.97%)]	Batch Loss: 0.064		Batch Accuracy: 98.44%
# Train Epoch: 69 [32512/60000 (54.19%)]	Batch Loss: 0.048		Batch Accuracy: 99.22%
# Train Epoch: 69 [32640/60000 (54.40%)]	Batch Loss: 0.009		Batch Accuracy: 100.00%
# Train Epoch: 69 [32768/60000 (54.61%)]	Batch Loss: 0.041		Batch Accuracy: 98.44%
# Train Epoch: 69 [32896/60000 (54.83%)]	Batch Loss: 0.031		Batch Accuracy: 99.22%
# Train Epoch: 69 [33024/60000 (55.04%)]	Batch Loss: 0.054		Batch Accuracy: 98.44%
# Train Epoch: 69 [33152/60000 (55.25%)]	Batch Loss: 0.027		Batch Accuracy: 100.00%
# Train Epoch: 69 [33280/60000 (55.47%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [33408/60000 (55.68%)]	Batch Loss: 0.046		Batch Accuracy: 98.44%
# Train Epoch: 69 [33536/60000 (55.89%)]	Batch Loss: 0.030		Batch Accuracy: 98.44%
# Train Epoch: 69 [33664/60000 (56.11%)]	Batch Loss: 0.029		Batch Accuracy: 99.22%
# Train Epoch: 69 [33792/60000 (56.32%)]	Batch Loss: 0.036		Batch Accuracy: 98.44%
# Train Epoch: 69 [33920/60000 (56.53%)]	Batch Loss: 0.019		Batch Accuracy: 100.00%
# Train Epoch: 69 [34048/60000 (56.75%)]	Batch Loss: 0.026		Batch Accuracy: 99.22%
# Train Epoch: 69 [34176/60000 (56.96%)]	Batch Loss: 0.072		Batch Accuracy: 98.44%
# Train Epoch: 69 [34304/60000 (57.17%)]	Batch Loss: 0.067		Batch Accuracy: 96.88%
# Train Epoch: 69 [34432/60000 (57.39%)]	Batch Loss: 0.061		Batch Accuracy: 98.44%
# Train Epoch: 69 [34560/60000 (57.60%)]	Batch Loss: 0.023		Batch Accuracy: 99.22%
# Train Epoch: 69 [34688/60000 (57.81%)]	Batch Loss: 0.078		Batch Accuracy: 96.88%
# Train Epoch: 69 [34816/60000 (58.03%)]	Batch Loss: 0.024		Batch Accuracy: 98.44%
# Train Epoch: 69 [34944/60000 (58.24%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [35072/60000 (58.45%)]	Batch Loss: 0.101		Batch Accuracy: 96.88%
# Train Epoch: 69 [35200/60000 (58.67%)]	Batch Loss: 0.069		Batch Accuracy: 96.88%
# Train Epoch: 69 [35328/60000 (58.88%)]	Batch Loss: 0.036		Batch Accuracy: 98.44%
# Train Epoch: 69 [35456/60000 (59.09%)]	Batch Loss: 0.066		Batch Accuracy: 98.44%
# Train Epoch: 69 [35584/60000 (59.31%)]	Batch Loss: 0.045		Batch Accuracy: 98.44%
# Train Epoch: 69 [35712/60000 (59.52%)]	Batch Loss: 0.063		Batch Accuracy: 97.66%
# Train Epoch: 69 [35840/60000 (59.73%)]	Batch Loss: 0.057		Batch Accuracy: 98.44%
# Train Epoch: 69 [35968/60000 (59.95%)]	Batch Loss: 0.040		Batch Accuracy: 99.22%
# Train Epoch: 69 [36096/60000 (60.16%)]	Batch Loss: 0.065		Batch Accuracy: 98.44%
# Train Epoch: 69 [36224/60000 (60.37%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [36352/60000 (60.59%)]	Batch Loss: 0.032		Batch Accuracy: 98.44%
# Train Epoch: 69 [36480/60000 (60.80%)]	Batch Loss: 0.022		Batch Accuracy: 100.00%
# Train Epoch: 69 [36608/60000 (61.01%)]	Batch Loss: 0.021		Batch Accuracy: 98.44%
# Train Epoch: 69 [36736/60000 (61.23%)]	Batch Loss: 0.048		Batch Accuracy: 97.66%
# Train Epoch: 69 [36864/60000 (61.44%)]	Batch Loss: 0.051		Batch Accuracy: 98.44%
# Train Epoch: 69 [36992/60000 (61.65%)]	Batch Loss: 0.058		Batch Accuracy: 98.44%
# Train Epoch: 69 [37120/60000 (61.87%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [37248/60000 (62.08%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [37376/60000 (62.29%)]	Batch Loss: 0.057		Batch Accuracy: 98.44%
# Train Epoch: 69 [37504/60000 (62.51%)]	Batch Loss: 0.089		Batch Accuracy: 96.88%
# Train Epoch: 69 [37632/60000 (62.72%)]	Batch Loss: 0.030		Batch Accuracy: 99.22%
# Train Epoch: 69 [37760/60000 (62.93%)]	Batch Loss: 0.034		Batch Accuracy: 98.44%
# Train Epoch: 69 [37888/60000 (63.15%)]	Batch Loss: 0.083		Batch Accuracy: 96.88%
# Train Epoch: 69 [38016/60000 (63.36%)]	Batch Loss: 0.022		Batch Accuracy: 99.22%
# Train Epoch: 69 [38144/60000 (63.57%)]	Batch Loss: 0.074		Batch Accuracy: 96.88%
# Train Epoch: 69 [38272/60000 (63.79%)]	Batch Loss: 0.022		Batch Accuracy: 99.22%
# Train Epoch: 69 [38400/60000 (64.00%)]	Batch Loss: 0.045		Batch Accuracy: 98.44%
# Train Epoch: 69 [38528/60000 (64.21%)]	Batch Loss: 0.025		Batch Accuracy: 99.22%
# Train Epoch: 69 [38656/60000 (64.43%)]	Batch Loss: 0.013		Batch Accuracy: 100.00%
# Train Epoch: 69 [38784/60000 (64.64%)]	Batch Loss: 0.072		Batch Accuracy: 97.66%
# Train Epoch: 69 [38912/60000 (64.85%)]	Batch Loss: 0.058		Batch Accuracy: 98.44%
# Train Epoch: 69 [39040/60000 (65.07%)]	Batch Loss: 0.055		Batch Accuracy: 98.44%
# Train Epoch: 69 [39168/60000 (65.28%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [39296/60000 (65.49%)]	Batch Loss: 0.010		Batch Accuracy: 100.00%
# Train Epoch: 69 [39424/60000 (65.71%)]	Batch Loss: 0.022		Batch Accuracy: 99.22%
# Train Epoch: 69 [39552/60000 (65.92%)]	Batch Loss: 0.089		Batch Accuracy: 96.88%
# Train Epoch: 69 [39680/60000 (66.13%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [39808/60000 (66.35%)]	Batch Loss: 0.013		Batch Accuracy: 100.00%
# Train Epoch: 69 [39936/60000 (66.56%)]	Batch Loss: 0.055		Batch Accuracy: 97.66%
# Train Epoch: 69 [40064/60000 (66.77%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [40192/60000 (66.99%)]	Batch Loss: 0.043		Batch Accuracy: 99.22%
# Train Epoch: 69 [40320/60000 (67.20%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [40448/60000 (67.41%)]	Batch Loss: 0.016		Batch Accuracy: 100.00%
# Train Epoch: 69 [40576/60000 (67.63%)]	Batch Loss: 0.065		Batch Accuracy: 97.66%
# Train Epoch: 69 [40704/60000 (67.84%)]	Batch Loss: 0.074		Batch Accuracy: 97.66%
# Train Epoch: 69 [40832/60000 (68.05%)]	Batch Loss: 0.053		Batch Accuracy: 98.44%
# Train Epoch: 69 [40960/60000 (68.27%)]	Batch Loss: 0.078		Batch Accuracy: 97.66%
# Train Epoch: 69 [41088/60000 (68.48%)]	Batch Loss: 0.053		Batch Accuracy: 99.22%
# Train Epoch: 69 [41216/60000 (68.69%)]	Batch Loss: 0.030		Batch Accuracy: 98.44%
# Train Epoch: 69 [41344/60000 (68.91%)]	Batch Loss: 0.025		Batch Accuracy: 99.22%
# Train Epoch: 69 [41472/60000 (69.12%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [41600/60000 (69.33%)]	Batch Loss: 0.056		Batch Accuracy: 98.44%
# Train Epoch: 69 [41728/60000 (69.55%)]	Batch Loss: 0.065		Batch Accuracy: 96.88%
# Train Epoch: 69 [41856/60000 (69.76%)]	Batch Loss: 0.077		Batch Accuracy: 98.44%
# Train Epoch: 69 [41984/60000 (69.97%)]	Batch Loss: 0.019		Batch Accuracy: 99.22%
# Train Epoch: 69 [42112/60000 (70.19%)]	Batch Loss: 0.024		Batch Accuracy: 99.22%
# Train Epoch: 69 [42240/60000 (70.40%)]	Batch Loss: 0.059		Batch Accuracy: 97.66%
# Train Epoch: 69 [42368/60000 (70.61%)]	Batch Loss: 0.011		Batch Accuracy: 100.00%
# Train Epoch: 69 [42496/60000 (70.83%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [42624/60000 (71.04%)]	Batch Loss: 0.031		Batch Accuracy: 99.22%
# Train Epoch: 69 [42752/60000 (71.25%)]	Batch Loss: 0.031		Batch Accuracy: 99.22%
# Train Epoch: 69 [42880/60000 (71.47%)]	Batch Loss: 0.016		Batch Accuracy: 99.22%
# Train Epoch: 69 [43008/60000 (71.68%)]	Batch Loss: 0.037		Batch Accuracy: 98.44%
# Train Epoch: 69 [43136/60000 (71.89%)]	Batch Loss: 0.027		Batch Accuracy: 98.44%
# Train Epoch: 69 [43264/60000 (72.11%)]	Batch Loss: 0.020		Batch Accuracy: 99.22%
# Train Epoch: 69 [43392/60000 (72.32%)]	Batch Loss: 0.085		Batch Accuracy: 98.44%
# Train Epoch: 69 [43520/60000 (72.53%)]	Batch Loss: 0.047		Batch Accuracy: 97.66%
# Train Epoch: 69 [43648/60000 (72.75%)]	Batch Loss: 0.038		Batch Accuracy: 98.44%
# Train Epoch: 69 [43776/60000 (72.96%)]	Batch Loss: 0.086		Batch Accuracy: 96.88%
# Train Epoch: 69 [43904/60000 (73.17%)]	Batch Loss: 0.081		Batch Accuracy: 98.44%
# Train Epoch: 69 [44032/60000 (73.39%)]	Batch Loss: 0.050		Batch Accuracy: 98.44%
# Train Epoch: 69 [44160/60000 (73.60%)]	Batch Loss: 0.094		Batch Accuracy: 96.09%
# Train Epoch: 69 [44288/60000 (73.81%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [44416/60000 (74.03%)]	Batch Loss: 0.052		Batch Accuracy: 99.22%
# Train Epoch: 69 [44544/60000 (74.24%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [44672/60000 (74.45%)]	Batch Loss: 0.027		Batch Accuracy: 98.44%
# Train Epoch: 69 [44800/60000 (74.67%)]	Batch Loss: 0.021		Batch Accuracy: 99.22%
# Train Epoch: 69 [44928/60000 (74.88%)]	Batch Loss: 0.060		Batch Accuracy: 98.44%
# Train Epoch: 69 [45056/60000 (75.09%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [45184/60000 (75.31%)]	Batch Loss: 0.041		Batch Accuracy: 98.44%
# Train Epoch: 69 [45312/60000 (75.52%)]	Batch Loss: 0.028		Batch Accuracy: 99.22%
# Train Epoch: 69 [45440/60000 (75.73%)]	Batch Loss: 0.049		Batch Accuracy: 98.44%
# Train Epoch: 69 [45568/60000 (75.95%)]	Batch Loss: 0.092		Batch Accuracy: 96.09%
# Train Epoch: 69 [45696/60000 (76.16%)]	Batch Loss: 0.066		Batch Accuracy: 97.66%
# Train Epoch: 69 [45824/60000 (76.37%)]	Batch Loss: 0.079		Batch Accuracy: 97.66%
# Train Epoch: 69 [45952/60000 (76.59%)]	Batch Loss: 0.018		Batch Accuracy: 100.00%
# Train Epoch: 69 [46080/60000 (76.80%)]	Batch Loss: 0.048		Batch Accuracy: 98.44%
# Train Epoch: 69 [46208/60000 (77.01%)]	Batch Loss: 0.069		Batch Accuracy: 96.88%
# Train Epoch: 69 [46336/60000 (77.23%)]	Batch Loss: 0.090		Batch Accuracy: 96.88%
# Train Epoch: 69 [46464/60000 (77.44%)]	Batch Loss: 0.076		Batch Accuracy: 97.66%
# Train Epoch: 69 [46592/60000 (77.65%)]	Batch Loss: 0.022		Batch Accuracy: 98.44%
# Train Epoch: 69 [46720/60000 (77.87%)]	Batch Loss: 0.053		Batch Accuracy: 98.44%
# Train Epoch: 69 [46848/60000 (78.08%)]	Batch Loss: 0.060		Batch Accuracy: 98.44%
# Train Epoch: 69 [46976/60000 (78.29%)]	Batch Loss: 0.033		Batch Accuracy: 99.22%
# Train Epoch: 69 [47104/60000 (78.51%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [47232/60000 (78.72%)]	Batch Loss: 0.021		Batch Accuracy: 99.22%
# Train Epoch: 69 [47360/60000 (78.93%)]	Batch Loss: 0.044		Batch Accuracy: 97.66%
# Train Epoch: 69 [47488/60000 (79.15%)]	Batch Loss: 0.045		Batch Accuracy: 98.44%
# Train Epoch: 69 [47616/60000 (79.36%)]	Batch Loss: 0.015		Batch Accuracy: 100.00%
# Train Epoch: 69 [47744/60000 (79.57%)]	Batch Loss: 0.049		Batch Accuracy: 97.66%
# Train Epoch: 69 [47872/60000 (79.79%)]	Batch Loss: 0.051		Batch Accuracy: 98.44%
# Train Epoch: 69 [48000/60000 (80.00%)]	Batch Loss: 0.042		Batch Accuracy: 98.44%
# Train Epoch: 69 [48128/60000 (80.21%)]	Batch Loss: 0.036		Batch Accuracy: 99.22%
# Train Epoch: 69 [48256/60000 (80.43%)]	Batch Loss: 0.090		Batch Accuracy: 96.88%
# Train Epoch: 69 [48384/60000 (80.64%)]	Batch Loss: 0.048		Batch Accuracy: 98.44%
# Train Epoch: 69 [48512/60000 (80.85%)]	Batch Loss: 0.031		Batch Accuracy: 99.22%
# Train Epoch: 69 [48640/60000 (81.07%)]	Batch Loss: 0.018		Batch Accuracy: 99.22%
# Train Epoch: 69 [48768/60000 (81.28%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [48896/60000 (81.49%)]	Batch Loss: 0.093		Batch Accuracy: 97.66%
# Train Epoch: 69 [49024/60000 (81.71%)]	Batch Loss: 0.083		Batch Accuracy: 97.66%
# Train Epoch: 69 [49152/60000 (81.92%)]	Batch Loss: 0.079		Batch Accuracy: 96.09%
# Train Epoch: 69 [49280/60000 (82.13%)]	Batch Loss: 0.029		Batch Accuracy: 98.44%
# Train Epoch: 69 [49408/60000 (82.35%)]	Batch Loss: 0.079		Batch Accuracy: 96.88%
# Train Epoch: 69 [49536/60000 (82.56%)]	Batch Loss: 0.068		Batch Accuracy: 96.88%
# Train Epoch: 69 [49664/60000 (82.77%)]	Batch Loss: 0.049		Batch Accuracy: 96.88%
# Train Epoch: 69 [49792/60000 (82.99%)]	Batch Loss: 0.065		Batch Accuracy: 98.44%
# Train Epoch: 69 [49920/60000 (83.20%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [50048/60000 (83.41%)]	Batch Loss: 0.063		Batch Accuracy: 97.66%
# Train Epoch: 69 [50176/60000 (83.63%)]	Batch Loss: 0.050		Batch Accuracy: 98.44%
# Train Epoch: 69 [50304/60000 (83.84%)]	Batch Loss: 0.036		Batch Accuracy: 99.22%
# Train Epoch: 69 [50432/60000 (84.05%)]	Batch Loss: 0.036		Batch Accuracy: 98.44%
# Train Epoch: 69 [50560/60000 (84.27%)]	Batch Loss: 0.064		Batch Accuracy: 98.44%
# Train Epoch: 69 [50688/60000 (84.48%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [50816/60000 (84.69%)]	Batch Loss: 0.036		Batch Accuracy: 99.22%
# Train Epoch: 69 [50944/60000 (84.91%)]	Batch Loss: 0.051		Batch Accuracy: 99.22%
# Train Epoch: 69 [51072/60000 (85.12%)]	Batch Loss: 0.082		Batch Accuracy: 96.88%
# Train Epoch: 69 [51200/60000 (85.33%)]	Batch Loss: 0.016		Batch Accuracy: 100.00%
# Train Epoch: 69 [51328/60000 (85.55%)]	Batch Loss: 0.010		Batch Accuracy: 100.00%
# Train Epoch: 69 [51456/60000 (85.76%)]	Batch Loss: 0.007		Batch Accuracy: 100.00%
# Train Epoch: 69 [51584/60000 (85.97%)]	Batch Loss: 0.006		Batch Accuracy: 100.00%
# Train Epoch: 69 [51712/60000 (86.19%)]	Batch Loss: 0.063		Batch Accuracy: 97.66%
# Train Epoch: 69 [51840/60000 (86.40%)]	Batch Loss: 0.078		Batch Accuracy: 96.88%
# Train Epoch: 69 [51968/60000 (86.61%)]	Batch Loss: 0.060		Batch Accuracy: 97.66%
# Train Epoch: 69 [52096/60000 (86.83%)]	Batch Loss: 0.046		Batch Accuracy: 97.66%
# Train Epoch: 69 [52224/60000 (87.04%)]	Batch Loss: 0.019		Batch Accuracy: 100.00%
# Train Epoch: 69 [52352/60000 (87.25%)]	Batch Loss: 0.032		Batch Accuracy: 99.22%
# Train Epoch: 69 [52480/60000 (87.47%)]	Batch Loss: 0.108		Batch Accuracy: 97.66%
# Train Epoch: 69 [52608/60000 (87.68%)]	Batch Loss: 0.046		Batch Accuracy: 99.22%
# Train Epoch: 69 [52736/60000 (87.89%)]	Batch Loss: 0.028		Batch Accuracy: 99.22%
# Train Epoch: 69 [52864/60000 (88.11%)]	Batch Loss: 0.048		Batch Accuracy: 98.44%
# Train Epoch: 69 [52992/60000 (88.32%)]	Batch Loss: 0.064		Batch Accuracy: 97.66%
# Train Epoch: 69 [53120/60000 (88.53%)]	Batch Loss: 0.051		Batch Accuracy: 98.44%
# Train Epoch: 69 [53248/60000 (88.75%)]	Batch Loss: 0.074		Batch Accuracy: 97.66%
# Train Epoch: 69 [53376/60000 (88.96%)]	Batch Loss: 0.035		Batch Accuracy: 98.44%
# Train Epoch: 69 [53504/60000 (89.17%)]	Batch Loss: 0.029		Batch Accuracy: 98.44%
# Train Epoch: 69 [53632/60000 (89.39%)]	Batch Loss: 0.030		Batch Accuracy: 98.44%
# Train Epoch: 69 [53760/60000 (89.60%)]	Batch Loss: 0.078		Batch Accuracy: 98.44%
# Train Epoch: 69 [53888/60000 (89.81%)]	Batch Loss: 0.101		Batch Accuracy: 97.66%
# Train Epoch: 69 [54016/60000 (90.03%)]	Batch Loss: 0.013		Batch Accuracy: 99.22%
# Train Epoch: 69 [54144/60000 (90.24%)]	Batch Loss: 0.019		Batch Accuracy: 99.22%
# Train Epoch: 69 [54272/60000 (90.45%)]	Batch Loss: 0.012		Batch Accuracy: 100.00%
# Train Epoch: 69 [54400/60000 (90.67%)]	Batch Loss: 0.043		Batch Accuracy: 98.44%
# Train Epoch: 69 [54528/60000 (90.88%)]	Batch Loss: 0.091		Batch Accuracy: 96.88%
# Train Epoch: 69 [54656/60000 (91.09%)]	Batch Loss: 0.019		Batch Accuracy: 100.00%
# Train Epoch: 69 [54784/60000 (91.31%)]	Batch Loss: 0.014		Batch Accuracy: 100.00%
# Train Epoch: 69 [54912/60000 (91.52%)]	Batch Loss: 0.070		Batch Accuracy: 97.66%
# Train Epoch: 69 [55040/60000 (91.73%)]	Batch Loss: 0.033		Batch Accuracy: 98.44%
# Train Epoch: 69 [55168/60000 (91.95%)]	Batch Loss: 0.022		Batch Accuracy: 99.22%
# Train Epoch: 69 [55296/60000 (92.16%)]	Batch Loss: 0.017		Batch Accuracy: 100.00%
# Train Epoch: 69 [55424/60000 (92.37%)]	Batch Loss: 0.070		Batch Accuracy: 98.44%
# Train Epoch: 69 [55552/60000 (92.59%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [55680/60000 (92.80%)]	Batch Loss: 0.033		Batch Accuracy: 98.44%
# Train Epoch: 69 [55808/60000 (93.01%)]	Batch Loss: 0.034		Batch Accuracy: 99.22%
# Train Epoch: 69 [55936/60000 (93.23%)]	Batch Loss: 0.100		Batch Accuracy: 96.88%
# Train Epoch: 69 [56064/60000 (93.44%)]	Batch Loss: 0.027		Batch Accuracy: 99.22%
# Train Epoch: 69 [56192/60000 (93.65%)]	Batch Loss: 0.073		Batch Accuracy: 96.88%
# Train Epoch: 69 [56320/60000 (93.87%)]	Batch Loss: 0.050		Batch Accuracy: 96.88%
# Train Epoch: 69 [56448/60000 (94.08%)]	Batch Loss: 0.017		Batch Accuracy: 100.00%
# Train Epoch: 69 [56576/60000 (94.29%)]	Batch Loss: 0.070		Batch Accuracy: 99.22%
# Train Epoch: 69 [56704/60000 (94.51%)]	Batch Loss: 0.100		Batch Accuracy: 95.31%
# Train Epoch: 69 [56832/60000 (94.72%)]	Batch Loss: 0.071		Batch Accuracy: 97.66%
# Train Epoch: 69 [56960/60000 (94.93%)]	Batch Loss: 0.067		Batch Accuracy: 97.66%
# Train Epoch: 69 [57088/60000 (95.15%)]	Batch Loss: 0.076		Batch Accuracy: 96.09%
# Train Epoch: 69 [57216/60000 (95.36%)]	Batch Loss: 0.016		Batch Accuracy: 100.00%
# Train Epoch: 69 [57344/60000 (95.57%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [57472/60000 (95.79%)]	Batch Loss: 0.092		Batch Accuracy: 96.88%
# Train Epoch: 69 [57600/60000 (96.00%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [57728/60000 (96.21%)]	Batch Loss: 0.046		Batch Accuracy: 99.22%
# Train Epoch: 69 [57856/60000 (96.43%)]	Batch Loss: 0.018		Batch Accuracy: 99.22%
# Train Epoch: 69 [57984/60000 (96.64%)]	Batch Loss: 0.062		Batch Accuracy: 98.44%
# Train Epoch: 69 [58112/60000 (96.85%)]	Batch Loss: 0.039		Batch Accuracy: 98.44%
# Train Epoch: 69 [58240/60000 (97.07%)]	Batch Loss: 0.040		Batch Accuracy: 98.44%
# Train Epoch: 69 [58368/60000 (97.28%)]	Batch Loss: 0.089		Batch Accuracy: 96.88%
# Train Epoch: 69 [58496/60000 (97.49%)]	Batch Loss: 0.021		Batch Accuracy: 99.22%
# Train Epoch: 69 [58624/60000 (97.71%)]	Batch Loss: 0.128		Batch Accuracy: 96.88%
# Train Epoch: 69 [58752/60000 (97.92%)]	Batch Loss: 0.067		Batch Accuracy: 97.66%
# Train Epoch: 69 [58880/60000 (98.13%)]	Batch Loss: 0.087		Batch Accuracy: 97.66%
# Train Epoch: 69 [59008/60000 (98.35%)]	Batch Loss: 0.056		Batch Accuracy: 98.44%
# Train Epoch: 69 [59136/60000 (98.56%)]	Batch Loss: 0.022		Batch Accuracy: 100.00%
# Train Epoch: 69 [59264/60000 (98.77%)]	Batch Loss: 0.070		Batch Accuracy: 97.66%
# Train Epoch: 69 [59392/60000 (98.99%)]	Batch Loss: 0.037		Batch Accuracy: 99.22%
# Train Epoch: 69 [59520/60000 (99.20%)]	Batch Loss: 0.120		Batch Accuracy: 98.44%
# Train Epoch: 69 [59648/60000 (99.41%)]	Batch Loss: 0.061		Batch Accuracy: 97.66%
# Train Epoch: 69 [59776/60000 (99.63%)]	Batch Loss: 0.042		Batch Accuracy: 97.66%
# Train Epoch: 69 [59904/60000 (99.84%)]	Batch Loss: 0.020		Batch Accuracy: 100.00%
# Train Epoch: 69 [60000/60000 (100.00%)]	Batch Loss: 0.007		Batch Accuracy: 100.00%
# Train Epoch 69| Loss: 0.045	Accuracy: 98.51%
# Test Epoch 69| Loss: 0.092	Accuracy: 97.07%	Best Accuracy: 97.94

# %%
model.train_plot(train_log, 'Training Loss', 'Test Loss')

# %%
model.train_plot(train_log, 'Training Accuracy', 'Test Accuracy')
